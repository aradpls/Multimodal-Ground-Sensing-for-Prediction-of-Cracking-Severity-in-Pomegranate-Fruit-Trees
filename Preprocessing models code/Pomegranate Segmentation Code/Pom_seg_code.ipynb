# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install segmentation_models_pytorch
from IPython.display import clear_output
clear_output()

# %%
import os
import cv2
import numpy as np
from PIL import Image
from sklearn.preprocessing import MinMaxScaler
import torch
from torch.utils.data import Dataset, DataLoader
import segmentation_models_pytorch as smp
import random  # Import the random module
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torchvision import transforms
from sklearn.preprocessing import MinMaxScaler
import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
import torch.optim as optim
import albumentations as A
# Out:
# /usr/local/lib/python3.10/dist-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 1.4.24 (you have 1.4.20). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
#Creating augmnation for a better model
# Define the root directories
root_directory = "/content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code"
image_folder = os.path.join(root_directory, "image")
mask_folder = os.path.join(root_directory, "mask")

# Define transformations
transform = A.OneOf([  # Apply one of these transformations randomly
    A.HorizontalFlip(p=1.0),  # Flip horizontally
    A.ShiftScaleRotate(shift_limit=0.1, scale_limit=0.1, rotate_limit=15, p=1.0),  # Shift, scale, rotate
    A.RandomCrop(height=1600, width=2400, p=1.0)  # Random cropping for size adjustment
], p=1.0)  # Always apply one transformation


# Get the list of images
image_files = sorted(os.listdir(image_folder))

# Augment each image and save with a new name
for image_name in image_files:
    if image_name.endswith(".jpg"):
        image_path = os.path.join(image_folder, image_name)
        mask_path = os.path.join(mask_folder, image_name)  # Assume masks have the same name

        # Load the image and mask
        image = cv2.imread(image_path)
        mask = cv2.imread(mask_path)

        if image is None or mask is None:
            print(f"Skipping {image_name} due to loading error.")
            continue

        # Apply transformation
        augmented = transform(image=image, mask=mask)
        aug_image = augmented['image']
        aug_mask = augmented['mask']

        # Save the augmented image and mask with a new name
        aug_image_name = image_name.replace('.jpg', '_2.jpg')
        aug_mask_name = image_name.replace('.jpg', '_2.jpg')

        cv2.imwrite(os.path.join(image_folder, aug_image_name), aug_image)  # Save augmented image
        cv2.imwrite(os.path.join(mask_folder, aug_mask_name), aug_mask)  # Save augmented mask

        print(f"Augmented frame saved as {aug_image_name} and {aug_mask_name}.")
# Out:
# Augmented frame saved as FRAME 1_2.jpg and FRAME 1_2.jpg.
# Augmented frame saved as FRAME 10_2.jpg and FRAME 10_2.jpg.
# Augmented frame saved as FRAME 100_2.jpg and FRAME 100_2.jpg.
# Augmented frame saved as FRAME 100_2_2.jpg and FRAME 100_2_2.jpg.
# Augmented frame saved as FRAME 101_2.jpg and FRAME 101_2.jpg.
# Augmented frame saved as FRAME 101_2_2.jpg and FRAME 101_2_2.jpg.
# Augmented frame saved as FRAME 102_2.jpg and FRAME 102_2.jpg.
# Augmented frame saved as FRAME 102_2_2.jpg and FRAME 102_2_2.jpg.
# Augmented frame saved as FRAME 103_2.jpg and FRAME 103_2.jpg.
# Augmented frame saved as FRAME 103_2_2.jpg and FRAME 103_2_2.jpg.
# Augmented frame saved as FRAME 104_2.jpg and FRAME 104_2.jpg.
# Augmented frame saved as FRAME 104_2_2.jpg and FRAME 104_2_2.jpg.
# Augmented frame saved as FRAME 105_2.jpg and FRAME 105_2.jpg.
# Augmented frame saved as FRAME 105_2_2.jpg and FRAME 105_2_2.jpg.
# Augmented frame saved as FRAME 106_2.jpg and FRAME 106_2.jpg.
# Augmented frame saved as FRAME 106_2_2.jpg and FRAME 106_2_2.jpg.
# Augmented frame saved as FRAME 107_2.jpg and FRAME 107_2.jpg.
# Augmented frame saved as FRAME 107_2_2.jpg and FRAME 107_2_2.jpg.
# Augmented frame saved as FRAME 108_2.jpg and FRAME 108_2.jpg.
# Augmented frame saved as FRAME 108_2_2.jpg and FRAME 108_2_2.jpg.
# Augmented frame saved as FRAME 109_2.jpg and FRAME 109_2.jpg.
# Augmented frame saved as FRAME 109_2_2.jpg and FRAME 109_2_2.jpg.
# Augmented frame saved as FRAME 10_2_2.jpg and FRAME 10_2_2.jpg.
# Augmented frame saved as FRAME 11_2.jpg and FRAME 11_2.jpg.
# Augmented frame saved as FRAME 110_2.jpg and FRAME 110_2.jpg.
# Augmented frame saved as FRAME 110_2_2.jpg and FRAME 110_2_2.jpg.
# Augmented frame saved as FRAME 111_2.jpg and FRAME 111_2.jpg.
# Augmented frame saved as FRAME 111_2_2.jpg and FRAME 111_2_2.jpg.
# Augmented frame saved as FRAME 112_2.jpg and FRAME 112_2.jpg.
# Augmented frame saved as FRAME 112_2_2.jpg and FRAME 112_2_2.jpg.
# Augmented frame saved as FRAME 113_2.jpg and FRAME 113_2.jpg.
# Augmented frame saved as FRAME 113_2_2.jpg and FRAME 113_2_2.jpg.
# Augmented frame saved as FRAME 114_2.jpg and FRAME 114_2.jpg.
# Augmented frame saved as FRAME 114_2_2.jpg and FRAME 114_2_2.jpg.
# Augmented frame saved as FRAME 115_2.jpg and FRAME 115_2.jpg.
# Augmented frame saved as FRAME 115_2_2.jpg and FRAME 115_2_2.jpg.
# Augmented frame saved as FRAME 116_2.jpg and FRAME 116_2.jpg.
# Augmented frame saved as FRAME 116_2_2.jpg and FRAME 116_2_2.jpg.
# Augmented frame saved as FRAME 117_2.jpg and FRAME 117_2.jpg.
# Augmented frame saved as FRAME 117_2_2.jpg and FRAME 117_2_2.jpg.
# Augmented frame saved as FRAME 118_2.jpg and FRAME 118_2.jpg.
# Augmented frame saved as FRAME 118_2_2.jpg and FRAME 118_2_2.jpg.
# Augmented frame saved as FRAME 119_2.jpg and FRAME 119_2.jpg.
# Augmented frame saved as FRAME 119_2_2.jpg and FRAME 119_2_2.jpg.
# Augmented frame saved as FRAME 11_2_2.jpg and FRAME 11_2_2.jpg.
# Augmented frame saved as FRAME 12_2.jpg and FRAME 12_2.jpg.
# Augmented frame saved as FRAME 120_2.jpg and FRAME 120_2.jpg.
# Augmented frame saved as FRAME 120_2_2.jpg and FRAME 120_2_2.jpg.
# Augmented frame saved as FRAME 121_2.jpg and FRAME 121_2.jpg.
# Augmented frame saved as FRAME 121_2_2.jpg and FRAME 121_2_2.jpg.
# Augmented frame saved as FRAME 122_2.jpg and FRAME 122_2.jpg.
# Augmented frame saved as FRAME 122_2_2.jpg and FRAME 122_2_2.jpg.
# Augmented frame saved as FRAME 123_2.jpg and FRAME 123_2.jpg.
# Augmented frame saved as FRAME 123_2_2.jpg and FRAME 123_2_2.jpg.
# Augmented frame saved as FRAME 124_2.jpg and FRAME 124_2.jpg.
# Augmented frame saved as FRAME 124_2_2.jpg and FRAME 124_2_2.jpg.
# Augmented frame saved as FRAME 125_2.jpg and FRAME 125_2.jpg.
# Augmented frame saved as FRAME 125_2_2.jpg and FRAME 125_2_2.jpg.
# Augmented frame saved as FRAME 126_2.jpg and FRAME 126_2.jpg.
# Augmented frame saved as FRAME 126_2_2.jpg and FRAME 126_2_2.jpg.
# Augmented frame saved as FRAME 127_2.jpg and FRAME 127_2.jpg.
# Augmented frame saved as FRAME 127_2_2.jpg and FRAME 127_2_2.jpg.
# Augmented frame saved as FRAME 128_2.jpg and FRAME 128_2.jpg.
# Augmented frame saved as FRAME 128_2_2.jpg and FRAME 128_2_2.jpg.
# Augmented frame saved as FRAME 129_2.jpg and FRAME 129_2.jpg.
# Augmented frame saved as FRAME 129_2_2.jpg and FRAME 129_2_2.jpg.
# Augmented frame saved as FRAME 12_2_2.jpg and FRAME 12_2_2.jpg.
# Augmented frame saved as FRAME 13_2.jpg and FRAME 13_2.jpg.
# Augmented frame saved as FRAME 130_2.jpg and FRAME 130_2.jpg.
# Augmented frame saved as FRAME 130_2_2.jpg and FRAME 130_2_2.jpg.
# Augmented frame saved as FRAME 131_2.jpg and FRAME 131_2.jpg.
# Augmented frame saved as FRAME 131_2_2.jpg and FRAME 131_2_2.jpg.
# Augmented frame saved as FRAME 132_2.jpg and FRAME 132_2.jpg.
# Augmented frame saved as FRAME 132_2_2.jpg and FRAME 132_2_2.jpg.
# Augmented frame saved as FRAME 133_2.jpg and FRAME 133_2.jpg.
# Augmented frame saved as FRAME 133_2_2.jpg and FRAME 133_2_2.jpg.
# Augmented frame saved as FRAME 134_2.jpg and FRAME 134_2.jpg.
# Augmented frame saved as FRAME 134_2_2.jpg and FRAME 134_2_2.jpg.
# Augmented frame saved as FRAME 135_2.jpg and FRAME 135_2.jpg.
# Augmented frame saved as FRAME 135_2_2.jpg and FRAME 135_2_2.jpg.
# Augmented frame saved as FRAME 136_2.jpg and FRAME 136_2.jpg.
# Augmented frame saved as FRAME 136_2_2.jpg and FRAME 136_2_2.jpg.
# Augmented frame saved as FRAME 137_2.jpg and FRAME 137_2.jpg.
# Augmented frame saved as FRAME 137_2_2.jpg and FRAME 137_2_2.jpg.
# Augmented frame saved as FRAME 138_2.jpg and FRAME 138_2.jpg.
# Augmented frame saved as FRAME 138_2_2.jpg and FRAME 138_2_2.jpg.
# Augmented frame saved as FRAME 139_2.jpg and FRAME 139_2.jpg.
# Augmented frame saved as FRAME 139_2_2.jpg and FRAME 139_2_2.jpg.
# Augmented frame saved as FRAME 13_2_2.jpg and FRAME 13_2_2.jpg.
# Augmented frame saved as FRAME 14_2.jpg and FRAME 14_2.jpg.
# Augmented frame saved as FRAME 140_2.jpg and FRAME 140_2.jpg.
# Augmented frame saved as FRAME 140_2_2.jpg and FRAME 140_2_2.jpg.
# Augmented frame saved as FRAME 141_2.jpg and FRAME 141_2.jpg.
# Augmented frame saved as FRAME 141_2_2.jpg and FRAME 141_2_2.jpg.
# Augmented frame saved as FRAME 142_2.jpg and FRAME 142_2.jpg.
# Augmented frame saved as FRAME 142_2_2.jpg and FRAME 142_2_2.jpg.
# Augmented frame saved as FRAME 143_2.jpg and FRAME 143_2.jpg.
# Augmented frame saved as FRAME 143_2_2.jpg and FRAME 143_2_2.jpg.
# Augmented frame saved as FRAME 144_2.jpg and FRAME 144_2.jpg.
# Augmented frame saved as FRAME 144_2_2.jpg and FRAME 144_2_2.jpg.
# Augmented frame saved as FRAME 145_2.jpg and FRAME 145_2.jpg.
# Augmented frame saved as FRAME 145_2_2.jpg and FRAME 145_2_2.jpg.
# Augmented frame saved as FRAME 146_2.jpg and FRAME 146_2.jpg.
# Augmented frame saved as FRAME 146_2_2.jpg and FRAME 146_2_2.jpg.
# Augmented frame saved as FRAME 147_2.jpg and FRAME 147_2.jpg.
# Augmented frame saved as FRAME 147_2_2.jpg and FRAME 147_2_2.jpg.
# Augmented frame saved as FRAME 148_2.jpg and FRAME 148_2.jpg.
# Augmented frame saved as FRAME 148_2_2.jpg and FRAME 148_2_2.jpg.
# Augmented frame saved as FRAME 149_2.jpg and FRAME 149_2.jpg.
# Augmented frame saved as FRAME 149_2_2.jpg and FRAME 149_2_2.jpg.
# Augmented frame saved as FRAME 14_2_2.jpg and FRAME 14_2_2.jpg.
# Augmented frame saved as FRAME 15_2.jpg and FRAME 15_2.jpg.
# Augmented frame saved as FRAME 150_2.jpg and FRAME 150_2.jpg.
# Augmented frame saved as FRAME 150_2_2.jpg and FRAME 150_2_2.jpg.
# Augmented frame saved as FRAME 151_2.jpg and FRAME 151_2.jpg.
# Augmented frame saved as FRAME 151_2_2.jpg and FRAME 151_2_2.jpg.
# Augmented frame saved as FRAME 152_2.jpg and FRAME 152_2.jpg.
# Augmented frame saved as FRAME 152_2_2.jpg and FRAME 152_2_2.jpg.
# Augmented frame saved as FRAME 153_2.jpg and FRAME 153_2.jpg.
# Augmented frame saved as FRAME 153_2_2.jpg and FRAME 153_2_2.jpg.
# Augmented frame saved as FRAME 154_2.jpg and FRAME 154_2.jpg.
# Augmented frame saved as FRAME 154_2_2.jpg and FRAME 154_2_2.jpg.
# Augmented frame saved as FRAME 155_2.jpg and FRAME 155_2.jpg.
# Augmented frame saved as FRAME 155_2_2.jpg and FRAME 155_2_2.jpg.
# Augmented frame saved as FRAME 156_2.jpg and FRAME 156_2.jpg.
# Augmented frame saved as FRAME 156_2_2.jpg and FRAME 156_2_2.jpg.
# Augmented frame saved as FRAME 157_2.jpg and FRAME 157_2.jpg.
# Augmented frame saved as FRAME 157_2_2.jpg and FRAME 157_2_2.jpg.
# Augmented frame saved as FRAME 158_2.jpg and FRAME 158_2.jpg.
# Augmented frame saved as FRAME 158_2_2.jpg and FRAME 158_2_2.jpg.
# Augmented frame saved as FRAME 159_2.jpg and FRAME 159_2.jpg.
# Augmented frame saved as FRAME 159_2_2.jpg and FRAME 159_2_2.jpg.
# Augmented frame saved as FRAME 15_2_2.jpg and FRAME 15_2_2.jpg.
# Augmented frame saved as FRAME 16_2.jpg and FRAME 16_2.jpg.
# Augmented frame saved as FRAME 160_2.jpg and FRAME 160_2.jpg.
# Augmented frame saved as FRAME 160_2_2.jpg and FRAME 160_2_2.jpg.
# Augmented frame saved as FRAME 161_2.jpg and FRAME 161_2.jpg.
# Augmented frame saved as FRAME 161_2_2.jpg and FRAME 161_2_2.jpg.
# Augmented frame saved as FRAME 162_2.jpg and FRAME 162_2.jpg.
# Augmented frame saved as FRAME 162_2_2.jpg and FRAME 162_2_2.jpg.
# Augmented frame saved as FRAME 163_2.jpg and FRAME 163_2.jpg.
# Augmented frame saved as FRAME 163_2_2.jpg and FRAME 163_2_2.jpg.
# Augmented frame saved as FRAME 164_2.jpg and FRAME 164_2.jpg.
# Augmented frame saved as FRAME 164_2_2.jpg and FRAME 164_2_2.jpg.
# Augmented frame saved as FRAME 165_2.jpg and FRAME 165_2.jpg.
# Augmented frame saved as FRAME 165_2_2.jpg and FRAME 165_2_2.jpg.
# Augmented frame saved as FRAME 166_2.jpg and FRAME 166_2.jpg.
# Augmented frame saved as FRAME 166_2_2.jpg and FRAME 166_2_2.jpg.
# Augmented frame saved as FRAME 167_2.jpg and FRAME 167_2.jpg.
# Augmented frame saved as FRAME 167_2_2.jpg and FRAME 167_2_2.jpg.
# Augmented frame saved as FRAME 168_2.jpg and FRAME 168_2.jpg.
# Augmented frame saved as FRAME 168_2_2.jpg and FRAME 168_2_2.jpg.
# Augmented frame saved as FRAME 169_2.jpg and FRAME 169_2.jpg.
# Augmented frame saved as FRAME 169_2_2.jpg and FRAME 169_2_2.jpg.
# Augmented frame saved as FRAME 16_2_2.jpg and FRAME 16_2_2.jpg.
# Augmented frame saved as FRAME 17_2.jpg and FRAME 17_2.jpg.
# Augmented frame saved as FRAME 170_2.jpg and FRAME 170_2.jpg.
# Augmented frame saved as FRAME 170_2_2.jpg and FRAME 170_2_2.jpg.
# Augmented frame saved as FRAME 171_2.jpg and FRAME 171_2.jpg.
# Augmented frame saved as FRAME 171_2_2.jpg and FRAME 171_2_2.jpg.
# Augmented frame saved as FRAME 172_2.jpg and FRAME 172_2.jpg.
# Augmented frame saved as FRAME 172_2_2.jpg and FRAME 172_2_2.jpg.
# Augmented frame saved as FRAME 173_2.jpg and FRAME 173_2.jpg.
# Augmented frame saved as FRAME 173_2_2.jpg and FRAME 173_2_2.jpg.
# Augmented frame saved as FRAME 174_2.jpg and FRAME 174_2.jpg.
# Augmented frame saved as FRAME 174_2_2.jpg and FRAME 174_2_2.jpg.
# Augmented frame saved as FRAME 175_2.jpg and FRAME 175_2.jpg.
# Augmented frame saved as FRAME 175_2_2.jpg and FRAME 175_2_2.jpg.
# Augmented frame saved as FRAME 176_2.jpg and FRAME 176_2.jpg.
# Augmented frame saved as FRAME 176_2_2.jpg and FRAME 176_2_2.jpg.
# Augmented frame saved as FRAME 177_2.jpg and FRAME 177_2.jpg.
# Augmented frame saved as FRAME 177_2_2.jpg and FRAME 177_2_2.jpg.
# Augmented frame saved as FRAME 178_2.jpg and FRAME 178_2.jpg.
# Augmented frame saved as FRAME 178_2_2.jpg and FRAME 178_2_2.jpg.
# Augmented frame saved as FRAME 179_2.jpg and FRAME 179_2.jpg.
# Augmented frame saved as FRAME 179_2_2.jpg and FRAME 179_2_2.jpg.
# Augmented frame saved as FRAME 17_2_2.jpg and FRAME 17_2_2.jpg.
# Augmented frame saved as FRAME 18_2.jpg and FRAME 18_2.jpg.
# Augmented frame saved as FRAME 180_2.jpg and FRAME 180_2.jpg.
# Augmented frame saved as FRAME 180_2_2.jpg and FRAME 180_2_2.jpg.
# Augmented frame saved as FRAME 181_2.jpg and FRAME 181_2.jpg.
# Augmented frame saved as FRAME 181_2_2.jpg and FRAME 181_2_2.jpg.
# Augmented frame saved as FRAME 182_2.jpg and FRAME 182_2.jpg.
# Augmented frame saved as FRAME 182_2_2.jpg and FRAME 182_2_2.jpg.
# Augmented frame saved as FRAME 183_2.jpg and FRAME 183_2.jpg.
# Augmented frame saved as FRAME 183_2_2.jpg and FRAME 183_2_2.jpg.
# Augmented frame saved as FRAME 184_2.jpg and FRAME 184_2.jpg.
# Augmented frame saved as FRAME 184_2_2.jpg and FRAME 184_2_2.jpg.
# Augmented frame saved as FRAME 185_2.jpg and FRAME 185_2.jpg.
# Augmented frame saved as FRAME 185_2_2.jpg and FRAME 185_2_2.jpg.
# Augmented frame saved as FRAME 186_2.jpg and FRAME 186_2.jpg.
# Augmented frame saved as FRAME 186_2_2.jpg and FRAME 186_2_2.jpg.
# Augmented frame saved as FRAME 187_2.jpg and FRAME 187_2.jpg.
# Augmented frame saved as FRAME 187_2_2.jpg and FRAME 187_2_2.jpg.
# Augmented frame saved as FRAME 188_2.jpg and FRAME 188_2.jpg.
# Augmented frame saved as FRAME 188_2_2.jpg and FRAME 188_2_2.jpg.
# Augmented frame saved as FRAME 189_2.jpg and FRAME 189_2.jpg.
# Augmented frame saved as FRAME 189_2_2.jpg and FRAME 189_2_2.jpg.
# Augmented frame saved as FRAME 18_2_2.jpg and FRAME 18_2_2.jpg.
# Augmented frame saved as FRAME 19_2.jpg and FRAME 19_2.jpg.
# Augmented frame saved as FRAME 190_2.jpg and FRAME 190_2.jpg.
# Augmented frame saved as FRAME 190_2_2.jpg and FRAME 190_2_2.jpg.
# Augmented frame saved as FRAME 191_2.jpg and FRAME 191_2.jpg.
# Augmented frame saved as FRAME 191_2_2.jpg and FRAME 191_2_2.jpg.
# Augmented frame saved as FRAME 192_2.jpg and FRAME 192_2.jpg.
# Augmented frame saved as FRAME 192_2_2.jpg and FRAME 192_2_2.jpg.
# Augmented frame saved as FRAME 193_2.jpg and FRAME 193_2.jpg.
# Augmented frame saved as FRAME 193_2_2.jpg and FRAME 193_2_2.jpg.
# Augmented frame saved as FRAME 194_2.jpg and FRAME 194_2.jpg.
# Augmented frame saved as FRAME 194_2_2.jpg and FRAME 194_2_2.jpg.
# Augmented frame saved as FRAME 195_2.jpg and FRAME 195_2.jpg.
# Augmented frame saved as FRAME 195_2_2.jpg and FRAME 195_2_2.jpg.
# Augmented frame saved as FRAME 196_2.jpg and FRAME 196_2.jpg.
# Augmented frame saved as FRAME 196_2_2.jpg and FRAME 196_2_2.jpg.
# Augmented frame saved as FRAME 197_2.jpg and FRAME 197_2.jpg.
# Augmented frame saved as FRAME 197_2_2.jpg and FRAME 197_2_2.jpg.
# Augmented frame saved as FRAME 198_2.jpg and FRAME 198_2.jpg.
# Augmented frame saved as FRAME 198_2_2.jpg and FRAME 198_2_2.jpg.
# Augmented frame saved as FRAME 199_2.jpg and FRAME 199_2.jpg.
# Augmented frame saved as FRAME 199_2_2.jpg and FRAME 199_2_2.jpg.
# Augmented frame saved as FRAME 19_2_2.jpg and FRAME 19_2_2.jpg.
# Augmented frame saved as FRAME 1_2_2.jpg and FRAME 1_2_2.jpg.
# Augmented frame saved as FRAME 2_2.jpg and FRAME 2_2.jpg.
# Augmented frame saved as FRAME 20_2.jpg and FRAME 20_2.jpg.
# Augmented frame saved as FRAME 200_2.jpg and FRAME 200_2.jpg.
# Augmented frame saved as FRAME 201_2.jpg and FRAME 201_2.jpg.
# Augmented frame saved as FRAME 202_2.jpg and FRAME 202_2.jpg.
# Augmented frame saved as FRAME 203_2.jpg and FRAME 203_2.jpg.
# Augmented frame saved as FRAME 204_2.jpg and FRAME 204_2.jpg.
# Augmented frame saved as FRAME 205_2.jpg and FRAME 205_2.jpg.
# Augmented frame saved as FRAME 206_2.jpg and FRAME 206_2.jpg.
# Augmented frame saved as FRAME 207_2.jpg and FRAME 207_2.jpg.
# Augmented frame saved as FRAME 208_2.jpg and FRAME 208_2.jpg.
# Augmented frame saved as FRAME 209_2.jpg and FRAME 209_2.jpg.
# Augmented frame saved as FRAME 21_2.jpg and FRAME 21_2.jpg.
# Augmented frame saved as FRAME 210_2.jpg and FRAME 210_2.jpg.
# Augmented frame saved as FRAME 211_2.jpg and FRAME 211_2.jpg.
# Augmented frame saved as FRAME 212_2.jpg and FRAME 212_2.jpg.
# Augmented frame saved as FRAME 213_2.jpg and FRAME 213_2.jpg.
# Augmented frame saved as FRAME 214_2.jpg and FRAME 214_2.jpg.
# Augmented frame saved as FRAME 215_2.jpg and FRAME 215_2.jpg.
# Augmented frame saved as FRAME 216_2.jpg and FRAME 216_2.jpg.
# Augmented frame saved as FRAME 217_2.jpg and FRAME 217_2.jpg.
# Augmented frame saved as FRAME 218_2.jpg and FRAME 218_2.jpg.
# Augmented frame saved as FRAME 219_2.jpg and FRAME 219_2.jpg.
# Augmented frame saved as FRAME 22_2.jpg and FRAME 22_2.jpg.
# Augmented frame saved as FRAME 220_2.jpg and FRAME 220_2.jpg.
# Augmented frame saved as FRAME 221_2.jpg and FRAME 221_2.jpg.
# Augmented frame saved as FRAME 222_2.jpg and FRAME 222_2.jpg.
# Augmented frame saved as FRAME 223_2.jpg and FRAME 223_2.jpg.
# Augmented frame saved as FRAME 224_2.jpg and FRAME 224_2.jpg.
# Augmented frame saved as FRAME 225_2.jpg and FRAME 225_2.jpg.
# Augmented frame saved as FRAME 226_2.jpg and FRAME 226_2.jpg.
# Augmented frame saved as FRAME 227_2.jpg and FRAME 227_2.jpg.
# Augmented frame saved as FRAME 228_2.jpg and FRAME 228_2.jpg.
# Augmented frame saved as FRAME 229_2.jpg and FRAME 229_2.jpg.
# Augmented frame saved as FRAME 23_2.jpg and FRAME 23_2.jpg.
# Augmented frame saved as FRAME 230_2.jpg and FRAME 230_2.jpg.
# Augmented frame saved as FRAME 231_2.jpg and FRAME 231_2.jpg.
# Augmented frame saved as FRAME 232_2.jpg and FRAME 232_2.jpg.
# Augmented frame saved as FRAME 233_2.jpg and FRAME 233_2.jpg.
# Augmented frame saved as FRAME 234_2.jpg and FRAME 234_2.jpg.
# Augmented frame saved as FRAME 235_2.jpg and FRAME 235_2.jpg.
# Augmented frame saved as FRAME 236_2.jpg and FRAME 236_2.jpg.
# Augmented frame saved as FRAME 237_2.jpg and FRAME 237_2.jpg.
# Augmented frame saved as FRAME 238_2.jpg and FRAME 238_2.jpg.
# Augmented frame saved as FRAME 239_2.jpg and FRAME 239_2.jpg.
# Augmented frame saved as FRAME 24_2.jpg and FRAME 24_2.jpg.
# Augmented frame saved as FRAME 240_2.jpg and FRAME 240_2.jpg.
# Augmented frame saved as FRAME 241_2.jpg and FRAME 241_2.jpg.
# Augmented frame saved as FRAME 242_2.jpg and FRAME 242_2.jpg.
# Augmented frame saved as FRAME 243_2.jpg and FRAME 243_2.jpg.
# Augmented frame saved as FRAME 244_2.jpg and FRAME 244_2.jpg.
# Augmented frame saved as FRAME 245_2.jpg and FRAME 245_2.jpg.
# Augmented frame saved as FRAME 246_2.jpg and FRAME 246_2.jpg.
# Augmented frame saved as FRAME 247_2.jpg and FRAME 247_2.jpg.
# Augmented frame saved as FRAME 248_2.jpg and FRAME 248_2.jpg.
# Augmented frame saved as FRAME 249_2.jpg and FRAME 249_2.jpg.
# Augmented frame saved as FRAME 25_2.jpg and FRAME 25_2.jpg.
# Augmented frame saved as FRAME 250_2.jpg and FRAME 250_2.jpg.
# Augmented frame saved as FRAME 251_2.jpg and FRAME 251_2.jpg.
# Augmented frame saved as FRAME 252_2.jpg and FRAME 252_2.jpg.
# Augmented frame saved as FRAME 253_2.jpg and FRAME 253_2.jpg.
# Augmented frame saved as FRAME 254_2.jpg and FRAME 254_2.jpg.
# Augmented frame saved as FRAME 255_2.jpg and FRAME 255_2.jpg.
# Augmented frame saved as FRAME 256_2.jpg and FRAME 256_2.jpg.
# Augmented frame saved as FRAME 257_2.jpg and FRAME 257_2.jpg.
# Augmented frame saved as FRAME 258_2.jpg and FRAME 258_2.jpg.
# Augmented frame saved as FRAME 259_2.jpg and FRAME 259_2.jpg.
# Augmented frame saved as FRAME 26_2.jpg and FRAME 26_2.jpg.
# Augmented frame saved as FRAME 260_2.jpg and FRAME 260_2.jpg.
# Augmented frame saved as FRAME 261_2.jpg and FRAME 261_2.jpg.
# Augmented frame saved as FRAME 262_2.jpg and FRAME 262_2.jpg.
# Augmented frame saved as FRAME 263_2.jpg and FRAME 263_2.jpg.
# Augmented frame saved as FRAME 264_2.jpg and FRAME 264_2.jpg.
# Augmented frame saved as FRAME 265_2.jpg and FRAME 265_2.jpg.
# Augmented frame saved as FRAME 266_2.jpg and FRAME 266_2.jpg.
# Augmented frame saved as FRAME 267_2.jpg and FRAME 267_2.jpg.
# Augmented frame saved as FRAME 268_2.jpg and FRAME 268_2.jpg.
# Augmented frame saved as FRAME 269_2.jpg and FRAME 269_2.jpg.
# Augmented frame saved as FRAME 27_2.jpg and FRAME 27_2.jpg.
# Augmented frame saved as FRAME 270_2.jpg and FRAME 270_2.jpg.
# Augmented frame saved as FRAME 271_2.jpg and FRAME 271_2.jpg.
# Augmented frame saved as FRAME 272_2.jpg and FRAME 272_2.jpg.
# Augmented frame saved as FRAME 273_2.jpg and FRAME 273_2.jpg.
# Augmented frame saved as FRAME 274_2.jpg and FRAME 274_2.jpg.
# Augmented frame saved as FRAME 275_2.jpg and FRAME 275_2.jpg.
# Augmented frame saved as FRAME 276_2.jpg and FRAME 276_2.jpg.
# Augmented frame saved as FRAME 277_2.jpg and FRAME 277_2.jpg.
# Augmented frame saved as FRAME 278_2.jpg and FRAME 278_2.jpg.
# Augmented frame saved as FRAME 279_2.jpg and FRAME 279_2.jpg.
# Augmented frame saved as FRAME 28_2.jpg and FRAME 28_2.jpg.
# Augmented frame saved as FRAME 280_2.jpg and FRAME 280_2.jpg.
# Augmented frame saved as FRAME 281_2.jpg and FRAME 281_2.jpg.
# Augmented frame saved as FRAME 282_2.jpg and FRAME 282_2.jpg.
# Augmented frame saved as FRAME 283_2.jpg and FRAME 283_2.jpg.
# Augmented frame saved as FRAME 284_2.jpg and FRAME 284_2.jpg.
# Augmented frame saved as FRAME 285_2.jpg and FRAME 285_2.jpg.
# Augmented frame saved as FRAME 286_2.jpg and FRAME 286_2.jpg.
# Augmented frame saved as FRAME 287_2.jpg and FRAME 287_2.jpg.
# Augmented frame saved as FRAME 288_2.jpg and FRAME 288_2.jpg.
# Augmented frame saved as FRAME 289_2.jpg and FRAME 289_2.jpg.
# Augmented frame saved as FRAME 29_2.jpg and FRAME 29_2.jpg.
# Augmented frame saved as FRAME 290_2.jpg and FRAME 290_2.jpg.
# Augmented frame saved as FRAME 291_2.jpg and FRAME 291_2.jpg.
# Augmented frame saved as FRAME 292_2.jpg and FRAME 292_2.jpg.
# Augmented frame saved as FRAME 293_2.jpg and FRAME 293_2.jpg.
# Augmented frame saved as FRAME 294_2.jpg and FRAME 294_2.jpg.
# Augmented frame saved as FRAME 295_2.jpg and FRAME 295_2.jpg.
# Augmented frame saved as FRAME 296_2.jpg and FRAME 296_2.jpg.
# Augmented frame saved as FRAME 297_2.jpg and FRAME 297_2.jpg.
# Augmented frame saved as FRAME 298_2.jpg and FRAME 298_2.jpg.
# Augmented frame saved as FRAME 299_2.jpg and FRAME 299_2.jpg.
# Augmented frame saved as FRAME 3_2.jpg and FRAME 3_2.jpg.
# Augmented frame saved as FRAME 30_2.jpg and FRAME 30_2.jpg.
# Augmented frame saved as FRAME 300_2.jpg and FRAME 300_2.jpg.
# Augmented frame saved as FRAME 301_2.jpg and FRAME 301_2.jpg.
# Augmented frame saved as FRAME 302_2.jpg and FRAME 302_2.jpg.
# Augmented frame saved as FRAME 303_2.jpg and FRAME 303_2.jpg.
# Augmented frame saved as FRAME 304_2.jpg and FRAME 304_2.jpg.
# Augmented frame saved as FRAME 305_2.jpg and FRAME 305_2.jpg.
# Augmented frame saved as FRAME 306_2.jpg and FRAME 306_2.jpg.
# Augmented frame saved as FRAME 307_2.jpg and FRAME 307_2.jpg.
# Augmented frame saved as FRAME 308_2.jpg and FRAME 308_2.jpg.
# Augmented frame saved as FRAME 309_2.jpg and FRAME 309_2.jpg.
# Augmented frame saved as FRAME 31_2.jpg and FRAME 31_2.jpg.
# Augmented frame saved as FRAME 310_2.jpg and FRAME 310_2.jpg.
# Augmented frame saved as FRAME 311_2.jpg and FRAME 311_2.jpg.
# Augmented frame saved as FRAME 312_2.jpg and FRAME 312_2.jpg.
# Augmented frame saved as FRAME 313_2.jpg and FRAME 313_2.jpg.
# Augmented frame saved as FRAME 314_2.jpg and FRAME 314_2.jpg.
# Augmented frame saved as FRAME 315_2.jpg and FRAME 315_2.jpg.
# Augmented frame saved as FRAME 316_2.jpg and FRAME 316_2.jpg.
# Augmented frame saved as FRAME 317_2.jpg and FRAME 317_2.jpg.
# Augmented frame saved as FRAME 318_2.jpg and FRAME 318_2.jpg.
# Augmented frame saved as FRAME 319_2.jpg and FRAME 319_2.jpg.
# Augmented frame saved as FRAME 32_2.jpg and FRAME 32_2.jpg.
# Augmented frame saved as FRAME 320_2.jpg and FRAME 320_2.jpg.
# Augmented frame saved as FRAME 321_2.jpg and FRAME 321_2.jpg.
# Augmented frame saved as FRAME 322_2.jpg and FRAME 322_2.jpg.
# Augmented frame saved as FRAME 323_2.jpg and FRAME 323_2.jpg.
# Augmented frame saved as FRAME 324_2.jpg and FRAME 324_2.jpg.
# Augmented frame saved as FRAME 325_2.jpg and FRAME 325_2.jpg.
# Augmented frame saved as FRAME 326_2.jpg and FRAME 326_2.jpg.
# Augmented frame saved as FRAME 327_2.jpg and FRAME 327_2.jpg.
# Augmented frame saved as FRAME 328_2.jpg and FRAME 328_2.jpg.
# Augmented frame saved as FRAME 329_2.jpg and FRAME 329_2.jpg.
# Augmented frame saved as FRAME 33_2.jpg and FRAME 33_2.jpg.
# Augmented frame saved as FRAME 330_2.jpg and FRAME 330_2.jpg.
# Augmented frame saved as FRAME 331_2.jpg and FRAME 331_2.jpg.
# Augmented frame saved as FRAME 332_2.jpg and FRAME 332_2.jpg.
# Augmented frame saved as FRAME 333_2.jpg and FRAME 333_2.jpg.
# Augmented frame saved as FRAME 334_2.jpg and FRAME 334_2.jpg.
# Augmented frame saved as FRAME 335_2.jpg and FRAME 335_2.jpg.
# Augmented frame saved as FRAME 336_2.jpg and FRAME 336_2.jpg.
# Augmented frame saved as FRAME 337_2.jpg and FRAME 337_2.jpg.
# Augmented frame saved as FRAME 338_2.jpg and FRAME 338_2.jpg.
# Augmented frame saved as FRAME 339_2.jpg and FRAME 339_2.jpg.
# Augmented frame saved as FRAME 34_2.jpg and FRAME 34_2.jpg.
# Augmented frame saved as FRAME 340_2.jpg and FRAME 340_2.jpg.
# Augmented frame saved as FRAME 341_2.jpg and FRAME 341_2.jpg.
# Augmented frame saved as FRAME 342_2.jpg and FRAME 342_2.jpg.
# Augmented frame saved as FRAME 343_2.jpg and FRAME 343_2.jpg.
# Augmented frame saved as FRAME 344_2.jpg and FRAME 344_2.jpg.
# Augmented frame saved as FRAME 345_2.jpg and FRAME 345_2.jpg.
# Augmented frame saved as FRAME 346_2.jpg and FRAME 346_2.jpg.
# Augmented frame saved as FRAME 347_2.jpg and FRAME 347_2.jpg.
# Augmented frame saved as FRAME 348_2.jpg and FRAME 348_2.jpg.
# Augmented frame saved as FRAME 349_2.jpg and FRAME 349_2.jpg.
# Augmented frame saved as FRAME 35_2.jpg and FRAME 35_2.jpg.
# Augmented frame saved as FRAME 350_2.jpg and FRAME 350_2.jpg.
# Augmented frame saved as FRAME 351_2.jpg and FRAME 351_2.jpg.
# Augmented frame saved as FRAME 352_2.jpg and FRAME 352_2.jpg.
# Augmented frame saved as FRAME 353_2.jpg and FRAME 353_2.jpg.
# Augmented frame saved as FRAME 354_2.jpg and FRAME 354_2.jpg.
# Augmented frame saved as FRAME 355_2.jpg and FRAME 355_2.jpg.
# Augmented frame saved as FRAME 356_2.jpg and FRAME 356_2.jpg.
# Augmented frame saved as FRAME 357_2.jpg and FRAME 357_2.jpg.
# Augmented frame saved as FRAME 358_2.jpg and FRAME 358_2.jpg.
# Augmented frame saved as FRAME 359_2.jpg and FRAME 359_2.jpg.
# Augmented frame saved as FRAME 36_2.jpg and FRAME 36_2.jpg.
# Augmented frame saved as FRAME 360_2.jpg and FRAME 360_2.jpg.
# Augmented frame saved as FRAME 361_2.jpg and FRAME 361_2.jpg.
# Augmented frame saved as FRAME 362_2.jpg and FRAME 362_2.jpg.
# Augmented frame saved as FRAME 363_2.jpg and FRAME 363_2.jpg.
# Augmented frame saved as FRAME 364_2.jpg and FRAME 364_2.jpg.
# Augmented frame saved as FRAME 365_2.jpg and FRAME 365_2.jpg.
# Augmented frame saved as FRAME 366_2.jpg and FRAME 366_2.jpg.
# Augmented frame saved as FRAME 367_2.jpg and FRAME 367_2.jpg.
# Augmented frame saved as FRAME 368_2.jpg and FRAME 368_2.jpg.
# Augmented frame saved as FRAME 369_2.jpg and FRAME 369_2.jpg.
# Augmented frame saved as FRAME 37_2.jpg and FRAME 37_2.jpg.
# Augmented frame saved as FRAME 370_2.jpg and FRAME 370_2.jpg.
# Augmented frame saved as FRAME 371_2.jpg and FRAME 371_2.jpg.
# Augmented frame saved as FRAME 372_2.jpg and FRAME 372_2.jpg.
# Augmented frame saved as FRAME 373_2.jpg and FRAME 373_2.jpg.
# Augmented frame saved as FRAME 374_2.jpg and FRAME 374_2.jpg.
# Augmented frame saved as FRAME 375_2.jpg and FRAME 375_2.jpg.
# Augmented frame saved as FRAME 376_2.jpg and FRAME 376_2.jpg.
# Augmented frame saved as FRAME 377_2.jpg and FRAME 377_2.jpg.
# Augmented frame saved as FRAME 378_2.jpg and FRAME 378_2.jpg.
# Augmented frame saved as FRAME 379_2.jpg and FRAME 379_2.jpg.
# Augmented frame saved as FRAME 38_2.jpg and FRAME 38_2.jpg.
# Augmented frame saved as FRAME 380_2.jpg and FRAME 380_2.jpg.
# Augmented frame saved as FRAME 381_2.jpg and FRAME 381_2.jpg.
# Augmented frame saved as FRAME 382_2.jpg and FRAME 382_2.jpg.
# Augmented frame saved as FRAME 383_2.jpg and FRAME 383_2.jpg.
# Augmented frame saved as FRAME 384_2.jpg and FRAME 384_2.jpg.
# Augmented frame saved as FRAME 385_2.jpg and FRAME 385_2.jpg.
# Augmented frame saved as FRAME 386_2.jpg and FRAME 386_2.jpg.
# Augmented frame saved as FRAME 387_2.jpg and FRAME 387_2.jpg.
# Augmented frame saved as FRAME 388_2.jpg and FRAME 388_2.jpg.
# Augmented frame saved as FRAME 389_2.jpg and FRAME 389_2.jpg.
# Augmented frame saved as FRAME 39_2.jpg and FRAME 39_2.jpg.
# Augmented frame saved as FRAME 390_2.jpg and FRAME 390_2.jpg.
# Augmented frame saved as FRAME 391_2.jpg and FRAME 391_2.jpg.
# Augmented frame saved as FRAME 392_2.jpg and FRAME 392_2.jpg.
# Augmented frame saved as FRAME 393_2.jpg and FRAME 393_2.jpg.
# Augmented frame saved as FRAME 394_2.jpg and FRAME 394_2.jpg.
# Augmented frame saved as FRAME 395_2.jpg and FRAME 395_2.jpg.
# Augmented frame saved as FRAME 396_2.jpg and FRAME 396_2.jpg.
# Augmented frame saved as FRAME 397_2.jpg and FRAME 397_2.jpg.
# Augmented frame saved as FRAME 398_2.jpg and FRAME 398_2.jpg.
# Augmented frame saved as FRAME 399_2.jpg and FRAME 399_2.jpg.
# Augmented frame saved as FRAME 4_2.jpg and FRAME 4_2.jpg.
# Augmented frame saved as FRAME 40_2.jpg and FRAME 40_2.jpg.
# Augmented frame saved as FRAME 400_2.jpg and FRAME 400_2.jpg.
# Augmented frame saved as FRAME 401_2.jpg and FRAME 401_2.jpg.
# Augmented frame saved as FRAME 402_2.jpg and FRAME 402_2.jpg.
# Augmented frame saved as FRAME 403_2.jpg and FRAME 403_2.jpg.
# Augmented frame saved as FRAME 404_2.jpg and FRAME 404_2.jpg.
# Augmented frame saved as FRAME 405_2.jpg and FRAME 405_2.jpg.
# Augmented frame saved as FRAME 406_2.jpg and FRAME 406_2.jpg.
# Augmented frame saved as FRAME 407_2.jpg and FRAME 407_2.jpg.
# Augmented frame saved as FRAME 408_2.jpg and FRAME 408_2.jpg.
# Augmented frame saved as FRAME 409_2.jpg and FRAME 409_2.jpg.
# Augmented frame saved as FRAME 41_2.jpg and FRAME 41_2.jpg.
# Augmented frame saved as FRAME 410_2.jpg and FRAME 410_2.jpg.
# Augmented frame saved as FRAME 411_2.jpg and FRAME 411_2.jpg.
# Augmented frame saved as FRAME 412_2.jpg and FRAME 412_2.jpg.
# Augmented frame saved as FRAME 413_2.jpg and FRAME 413_2.jpg.
# Augmented frame saved as FRAME 414_2.jpg and FRAME 414_2.jpg.
# Augmented frame saved as FRAME 415_2.jpg and FRAME 415_2.jpg.
# Augmented frame saved as FRAME 416_2.jpg and FRAME 416_2.jpg.
# Augmented frame saved as FRAME 417_2.jpg and FRAME 417_2.jpg.
# Augmented frame saved as FRAME 418_2.jpg and FRAME 418_2.jpg.
# Augmented frame saved as FRAME 419_2.jpg and FRAME 419_2.jpg.
# Augmented frame saved as FRAME 42_2.jpg and FRAME 42_2.jpg.
# Augmented frame saved as FRAME 420_2.jpg and FRAME 420_2.jpg.
# Augmented frame saved as FRAME 421_2.jpg and FRAME 421_2.jpg.
# Augmented frame saved as FRAME 422_2.jpg and FRAME 422_2.jpg.
# Augmented frame saved as FRAME 423_2.jpg and FRAME 423_2.jpg.
# Augmented frame saved as FRAME 424_2.jpg and FRAME 424_2.jpg.
# Augmented frame saved as FRAME 425_2.jpg and FRAME 425_2.jpg.
# Augmented frame saved as FRAME 426_2.jpg and FRAME 426_2.jpg.
# Augmented frame saved as FRAME 427_2.jpg and FRAME 427_2.jpg.
# Augmented frame saved as FRAME 428_2.jpg and FRAME 428_2.jpg.
# Augmented frame saved as FRAME 429_2.jpg and FRAME 429_2.jpg.
# Augmented frame saved as FRAME 43_2.jpg and FRAME 43_2.jpg.
# Augmented frame saved as FRAME 430_2.jpg and FRAME 430_2.jpg.
# Augmented frame saved as FRAME 431_2.jpg and FRAME 431_2.jpg.
# Augmented frame saved as FRAME 432_2.jpg and FRAME 432_2.jpg.
# Augmented frame saved as FRAME 433_2.jpg and FRAME 433_2.jpg.
# Augmented frame saved as FRAME 434_2.jpg and FRAME 434_2.jpg.
# Augmented frame saved as FRAME 435_2.jpg and FRAME 435_2.jpg.
# Augmented frame saved as FRAME 436_2.jpg and FRAME 436_2.jpg.
# Augmented frame saved as FRAME 437_2.jpg and FRAME 437_2.jpg.
# Augmented frame saved as FRAME 438_2.jpg and FRAME 438_2.jpg.
# Augmented frame saved as FRAME 439_2.jpg and FRAME 439_2.jpg.
# Augmented frame saved as FRAME 44_2.jpg and FRAME 44_2.jpg.
# Augmented frame saved as FRAME 440_2.jpg and FRAME 440_2.jpg.
# Augmented frame saved as FRAME 441_2.jpg and FRAME 441_2.jpg.
# Augmented frame saved as FRAME 442_2.jpg and FRAME 442_2.jpg.
# Augmented frame saved as FRAME 443_2.jpg and FRAME 443_2.jpg.
# Augmented frame saved as FRAME 444_2.jpg and FRAME 444_2.jpg.
# Augmented frame saved as FRAME 445_2.jpg and FRAME 445_2.jpg.
# Augmented frame saved as FRAME 446_2.jpg and FRAME 446_2.jpg.
# Augmented frame saved as FRAME 447_2.jpg and FRAME 447_2.jpg.
# Augmented frame saved as FRAME 448_2.jpg and FRAME 448_2.jpg.
# Augmented frame saved as FRAME 449_2.jpg and FRAME 449_2.jpg.
# Augmented frame saved as FRAME 45_2.jpg and FRAME 45_2.jpg.
# Augmented frame saved as FRAME 450_2.jpg and FRAME 450_2.jpg.
# Augmented frame saved as FRAME 451_2.jpg and FRAME 451_2.jpg.
# Augmented frame saved as FRAME 452_2.jpg and FRAME 452_2.jpg.
# Augmented frame saved as FRAME 453_2.jpg and FRAME 453_2.jpg.
# Augmented frame saved as FRAME 454_2.jpg and FRAME 454_2.jpg.
# Augmented frame saved as FRAME 455_2.jpg and FRAME 455_2.jpg.
# Augmented frame saved as FRAME 456_2.jpg and FRAME 456_2.jpg.
# Augmented frame saved as FRAME 457_2.jpg and FRAME 457_2.jpg.
# Augmented frame saved as FRAME 458_2.jpg and FRAME 458_2.jpg.
# Augmented frame saved as FRAME 459_2.jpg and FRAME 459_2.jpg.
# Augmented frame saved as FRAME 46_2.jpg and FRAME 46_2.jpg.
# Augmented frame saved as FRAME 460_2.jpg and FRAME 460_2.jpg.
# Augmented frame saved as FRAME 461_2.jpg and FRAME 461_2.jpg.
# Augmented frame saved as FRAME 462_2.jpg and FRAME 462_2.jpg.
# Augmented frame saved as FRAME 463_2.jpg and FRAME 463_2.jpg.
# Augmented frame saved as FRAME 464_2.jpg and FRAME 464_2.jpg.
# Augmented frame saved as FRAME 465_2.jpg and FRAME 465_2.jpg.
# Augmented frame saved as FRAME 466_2.jpg and FRAME 466_2.jpg.
# Augmented frame saved as FRAME 467_2.jpg and FRAME 467_2.jpg.
# Augmented frame saved as FRAME 468_2.jpg and FRAME 468_2.jpg.
# Augmented frame saved as FRAME 469_2.jpg and FRAME 469_2.jpg.
# Augmented frame saved as FRAME 47_2.jpg and FRAME 47_2.jpg.
# Augmented frame saved as FRAME 470_2.jpg and FRAME 470_2.jpg.
# Augmented frame saved as FRAME 471_2.jpg and FRAME 471_2.jpg.
# Augmented frame saved as FRAME 472_2.jpg and FRAME 472_2.jpg.
# Augmented frame saved as FRAME 473_2.jpg and FRAME 473_2.jpg.
# Augmented frame saved as FRAME 474_2.jpg and FRAME 474_2.jpg.
# Augmented frame saved as FRAME 475_2.jpg and FRAME 475_2.jpg.
# Augmented frame saved as FRAME 476_2.jpg and FRAME 476_2.jpg.
# Augmented frame saved as FRAME 477_2.jpg and FRAME 477_2.jpg.
# Augmented frame saved as FRAME 478_2.jpg and FRAME 478_2.jpg.
# Augmented frame saved as FRAME 479_2.jpg and FRAME 479_2.jpg.
# Augmented frame saved as FRAME 48_2.jpg and FRAME 48_2.jpg.
# Augmented frame saved as FRAME 480_2.jpg and FRAME 480_2.jpg.
# Augmented frame saved as FRAME 481_2.jpg and FRAME 481_2.jpg.
# Augmented frame saved as FRAME 482_2.jpg and FRAME 482_2.jpg.
# Augmented frame saved as FRAME 483_2.jpg and FRAME 483_2.jpg.
# Augmented frame saved as FRAME 484_2.jpg and FRAME 484_2.jpg.
# Augmented frame saved as FRAME 485_2.jpg and FRAME 485_2.jpg.
# Augmented frame saved as FRAME 486_2.jpg and FRAME 486_2.jpg.
# Augmented frame saved as FRAME 487_2.jpg and FRAME 487_2.jpg.
# Augmented frame saved as FRAME 488_2.jpg and FRAME 488_2.jpg.
# Augmented frame saved as FRAME 489_2.jpg and FRAME 489_2.jpg.
# Augmented frame saved as FRAME 49_2.jpg and FRAME 49_2.jpg.
# Augmented frame saved as FRAME 490_2.jpg and FRAME 490_2.jpg.
# Augmented frame saved as FRAME 491_2.jpg and FRAME 491_2.jpg.
# Augmented frame saved as FRAME 492_2.jpg and FRAME 492_2.jpg.
# Augmented frame saved as FRAME 493_2.jpg and FRAME 493_2.jpg.
# Augmented frame saved as FRAME 494_2.jpg and FRAME 494_2.jpg.
# Augmented frame saved as FRAME 495_2.jpg and FRAME 495_2.jpg.
# Augmented frame saved as FRAME 496_2.jpg and FRAME 496_2.jpg.
# Augmented frame saved as FRAME 497_2.jpg and FRAME 497_2.jpg.
# Augmented frame saved as FRAME 498_2.jpg and FRAME 498_2.jpg.
# Augmented frame saved as FRAME 499_2.jpg and FRAME 499_2.jpg.
# Augmented frame saved as FRAME 5_2.jpg and FRAME 5_2.jpg.
# Augmented frame saved as FRAME 50_2.jpg and FRAME 50_2.jpg.
# Augmented frame saved as FRAME 500_2.jpg and FRAME 500_2.jpg.
# Augmented frame saved as FRAME 501_2.jpg and FRAME 501_2.jpg.
# Augmented frame saved as FRAME 502_2.jpg and FRAME 502_2.jpg.
# Augmented frame saved as FRAME 503_2.jpg and FRAME 503_2.jpg.
# Augmented frame saved as FRAME 504_2.jpg and FRAME 504_2.jpg.
# Augmented frame saved as FRAME 505_2.jpg and FRAME 505_2.jpg.
# Augmented frame saved as FRAME 506_2.jpg and FRAME 506_2.jpg.
# Augmented frame saved as FRAME 507_2.jpg and FRAME 507_2.jpg.
# Augmented frame saved as FRAME 508_2.jpg and FRAME 508_2.jpg.
# Augmented frame saved as FRAME 509_2.jpg and FRAME 509_2.jpg.
# Augmented frame saved as FRAME 51_2.jpg and FRAME 51_2.jpg.
# Augmented frame saved as FRAME 510_2.jpg and FRAME 510_2.jpg.
# Augmented frame saved as FRAME 511_2.jpg and FRAME 511_2.jpg.
# Augmented frame saved as FRAME 512_2.jpg and FRAME 512_2.jpg.
# Augmented frame saved as FRAME 513_2.jpg and FRAME 513_2.jpg.
# Augmented frame saved as FRAME 514_2.jpg and FRAME 514_2.jpg.
# Augmented frame saved as FRAME 515_2.jpg and FRAME 515_2.jpg.
# Augmented frame saved as FRAME 516_2.jpg and FRAME 516_2.jpg.
# Augmented frame saved as FRAME 517_2.jpg and FRAME 517_2.jpg.
# Augmented frame saved as FRAME 518_2.jpg and FRAME 518_2.jpg.
# Augmented frame saved as FRAME 519_2.jpg and FRAME 519_2.jpg.
# Augmented frame saved as FRAME 52_2.jpg and FRAME 52_2.jpg.
# Augmented frame saved as FRAME 520_2.jpg and FRAME 520_2.jpg.
# Augmented frame saved as FRAME 521_2.jpg and FRAME 521_2.jpg.
# Augmented frame saved as FRAME 522_2.jpg and FRAME 522_2.jpg.
# Augmented frame saved as FRAME 523_2.jpg and FRAME 523_2.jpg.
# Augmented frame saved as FRAME 524_2.jpg and FRAME 524_2.jpg.
# Augmented frame saved as FRAME 525_2.jpg and FRAME 525_2.jpg.
# Augmented frame saved as FRAME 526_2.jpg and FRAME 526_2.jpg.
# Augmented frame saved as FRAME 527_2.jpg and FRAME 527_2.jpg.
# Augmented frame saved as FRAME 528_2.jpg and FRAME 528_2.jpg.
# Augmented frame saved as FRAME 529_2.jpg and FRAME 529_2.jpg.
# Augmented frame saved as FRAME 53_2.jpg and FRAME 53_2.jpg.
# Augmented frame saved as FRAME 530_2.jpg and FRAME 530_2.jpg.
# Augmented frame saved as FRAME 531_2.jpg and FRAME 531_2.jpg.
# Augmented frame saved as FRAME 532_2.jpg and FRAME 532_2.jpg.
# Augmented frame saved as FRAME 533_2.jpg and FRAME 533_2.jpg.
# Augmented frame saved as FRAME 534_2.jpg and FRAME 534_2.jpg.
# Augmented frame saved as FRAME 535_2.jpg and FRAME 535_2.jpg.
# Augmented frame saved as FRAME 536_2.jpg and FRAME 536_2.jpg.
# Augmented frame saved as FRAME 537_2.jpg and FRAME 537_2.jpg.
# Augmented frame saved as FRAME 538_2.jpg and FRAME 538_2.jpg.
# Augmented frame saved as FRAME 539_2.jpg and FRAME 539_2.jpg.
# Augmented frame saved as FRAME 54_2.jpg and FRAME 54_2.jpg.
# Augmented frame saved as FRAME 540_2.jpg and FRAME 540_2.jpg.
# Augmented frame saved as FRAME 541_2.jpg and FRAME 541_2.jpg.
# Augmented frame saved as FRAME 542_2.jpg and FRAME 542_2.jpg.
# Augmented frame saved as FRAME 543_2.jpg and FRAME 543_2.jpg.
# Augmented frame saved as FRAME 544_2.jpg and FRAME 544_2.jpg.
# Augmented frame saved as FRAME 545_2.jpg and FRAME 545_2.jpg.
# Augmented frame saved as FRAME 546_2.jpg and FRAME 546_2.jpg.
# Augmented frame saved as FRAME 547_2.jpg and FRAME 547_2.jpg.
# Augmented frame saved as FRAME 548_2.jpg and FRAME 548_2.jpg.
# Augmented frame saved as FRAME 549_2.jpg and FRAME 549_2.jpg.
# Augmented frame saved as FRAME 55_2.jpg and FRAME 55_2.jpg.
# Augmented frame saved as FRAME 550_2.jpg and FRAME 550_2.jpg.
# Augmented frame saved as FRAME 551_2.jpg and FRAME 551_2.jpg.
# Augmented frame saved as FRAME 552_2.jpg and FRAME 552_2.jpg.
# Augmented frame saved as FRAME 553_2.jpg and FRAME 553_2.jpg.
# Augmented frame saved as FRAME 554_2.jpg and FRAME 554_2.jpg.
# Augmented frame saved as FRAME 555_2.jpg and FRAME 555_2.jpg.
# Augmented frame saved as FRAME 556_2.jpg and FRAME 556_2.jpg.
# Augmented frame saved as FRAME 557_2.jpg and FRAME 557_2.jpg.
# Augmented frame saved as FRAME 558_2.jpg and FRAME 558_2.jpg.
# Augmented frame saved as FRAME 56_2.jpg and FRAME 56_2.jpg.
# Augmented frame saved as FRAME 562_2.jpg and FRAME 562_2.jpg.
# Augmented frame saved as FRAME 563_2.jpg and FRAME 563_2.jpg.
# Augmented frame saved as FRAME 564_2.jpg and FRAME 564_2.jpg.
# Augmented frame saved as FRAME 566_2.jpg and FRAME 566_2.jpg.
# Augmented frame saved as FRAME 568_2.jpg and FRAME 568_2.jpg.
# Augmented frame saved as FRAME 569_2.jpg and FRAME 569_2.jpg.
# Augmented frame saved as FRAME 57_2.jpg and FRAME 57_2.jpg.
# Augmented frame saved as FRAME 570_2.jpg and FRAME 570_2.jpg.
# Augmented frame saved as FRAME 574_2.jpg and FRAME 574_2.jpg.
# Augmented frame saved as FRAME 575_2.jpg and FRAME 575_2.jpg.
# Augmented frame saved as FRAME 576_2.jpg and FRAME 576_2.jpg.
# Augmented frame saved as FRAME 58_2.jpg and FRAME 58_2.jpg.
# Augmented frame saved as FRAME 580_2.jpg and FRAME 580_2.jpg.
# Augmented frame saved as FRAME 581_2.jpg and FRAME 581_2.jpg.
# Augmented frame saved as FRAME 582_2.jpg and FRAME 582_2.jpg.
# Augmented frame saved as FRAME 583_2.jpg and FRAME 583_2.jpg.
# Augmented frame saved as FRAME 584_2.jpg and FRAME 584_2.jpg.
# Augmented frame saved as FRAME 585_2.jpg and FRAME 585_2.jpg.
# Augmented frame saved as FRAME 586_2.jpg and FRAME 586_2.jpg.
# Augmented frame saved as FRAME 587_2.jpg and FRAME 587_2.jpg.
# Augmented frame saved as FRAME 588_2.jpg and FRAME 588_2.jpg.
# Augmented frame saved as FRAME 589_2.jpg and FRAME 589_2.jpg.
# Augmented frame saved as FRAME 59_2.jpg and FRAME 59_2.jpg.
# Augmented frame saved as FRAME 590_2.jpg and FRAME 590_2.jpg.
# Augmented frame saved as FRAME 591_2.jpg and FRAME 591_2.jpg.
# Augmented frame saved as FRAME 592_2.jpg and FRAME 592_2.jpg.
# Augmented frame saved as FRAME 593_2.jpg and FRAME 593_2.jpg.
# Augmented frame saved as FRAME 594_2.jpg and FRAME 594_2.jpg.
# Augmented frame saved as FRAME 595_2.jpg and FRAME 595_2.jpg.
# Augmented frame saved as FRAME 596_2.jpg and FRAME 596_2.jpg.
# Augmented frame saved as FRAME 597_2.jpg and FRAME 597_2.jpg.
# Augmented frame saved as FRAME 598_2.jpg and FRAME 598_2.jpg.
# Augmented frame saved as FRAME 599_2.jpg and FRAME 599_2.jpg.
# Augmented frame saved as FRAME 6_2.jpg and FRAME 6_2.jpg.
# Augmented frame saved as FRAME 60_2.jpg and FRAME 60_2.jpg.
# Augmented frame saved as FRAME 600_2.jpg and FRAME 600_2.jpg.
# Augmented frame saved as FRAME 601_2.jpg and FRAME 601_2.jpg.
# Augmented frame saved as FRAME 602_2.jpg and FRAME 602_2.jpg.
# Augmented frame saved as FRAME 603_2.jpg and FRAME 603_2.jpg.
# Augmented frame saved as FRAME 604_2.jpg and FRAME 604_2.jpg.
# Augmented frame saved as FRAME 605_2.jpg and FRAME 605_2.jpg.
# Augmented frame saved as FRAME 606_2.jpg and FRAME 606_2.jpg.
# Augmented frame saved as FRAME 607_2.jpg and FRAME 607_2.jpg.
# Augmented frame saved as FRAME 608_2.jpg and FRAME 608_2.jpg.
# Augmented frame saved as FRAME 609_2.jpg and FRAME 609_2.jpg.
# Augmented frame saved as FRAME 61_2.jpg and FRAME 61_2.jpg.
# Augmented frame saved as FRAME 610_2.jpg and FRAME 610_2.jpg.
# Augmented frame saved as FRAME 611_2.jpg and FRAME 611_2.jpg.
# Augmented frame saved as FRAME 612_2.jpg and FRAME 612_2.jpg.
# Augmented frame saved as FRAME 613_2.jpg and FRAME 613_2.jpg.
# Augmented frame saved as FRAME 614_2.jpg and FRAME 614_2.jpg.
# Augmented frame saved as FRAME 615_2.jpg and FRAME 615_2.jpg.
# Augmented frame saved as FRAME 616_2.jpg and FRAME 616_2.jpg.
# Augmented frame saved as FRAME 617_2.jpg and FRAME 617_2.jpg.
# Augmented frame saved as FRAME 618_2.jpg and FRAME 618_2.jpg.
# Augmented frame saved as FRAME 619_2.jpg and FRAME 619_2.jpg.
# Augmented frame saved as FRAME 62_2.jpg and FRAME 62_2.jpg.
# Augmented frame saved as FRAME 620_2.jpg and FRAME 620_2.jpg.
# Augmented frame saved as FRAME 621_2.jpg and FRAME 621_2.jpg.
# Augmented frame saved as FRAME 622_2.jpg and FRAME 622_2.jpg.
# Augmented frame saved as FRAME 623_2.jpg and FRAME 623_2.jpg.
# Augmented frame saved as FRAME 624_2.jpg and FRAME 624_2.jpg.
# Augmented frame saved as FRAME 625_2.jpg and FRAME 625_2.jpg.
# Augmented frame saved as FRAME 626_2.jpg and FRAME 626_2.jpg.
# Augmented frame saved as FRAME 627_2.jpg and FRAME 627_2.jpg.
# Augmented frame saved as FRAME 628_2.jpg and FRAME 628_2.jpg.
# Augmented frame saved as FRAME 629_2.jpg and FRAME 629_2.jpg.
# Augmented frame saved as FRAME 63_2.jpg and FRAME 63_2.jpg.
# Augmented frame saved as FRAME 630_2.jpg and FRAME 630_2.jpg.
# Augmented frame saved as FRAME 631_2.jpg and FRAME 631_2.jpg.
# Augmented frame saved as FRAME 632_2.jpg and FRAME 632_2.jpg.
# Augmented frame saved as FRAME 633_2.jpg and FRAME 633_2.jpg.
# Augmented frame saved as FRAME 634_2.jpg and FRAME 634_2.jpg.
# Augmented frame saved as FRAME 635_2.jpg and FRAME 635_2.jpg.
# Augmented frame saved as FRAME 636_2.jpg and FRAME 636_2.jpg.
# Augmented frame saved as FRAME 637_2.jpg and FRAME 637_2.jpg.
# Augmented frame saved as FRAME 638_2.jpg and FRAME 638_2.jpg.
# Augmented frame saved as FRAME 639_2.jpg and FRAME 639_2.jpg.
# Augmented frame saved as FRAME 64_2.jpg and FRAME 64_2.jpg.
# Augmented frame saved as FRAME 640_2.jpg and FRAME 640_2.jpg.
# Augmented frame saved as FRAME 641_2.jpg and FRAME 641_2.jpg.
# Augmented frame saved as FRAME 642_2.jpg and FRAME 642_2.jpg.
# Augmented frame saved as FRAME 643_2.jpg and FRAME 643_2.jpg.
# Augmented frame saved as FRAME 644_2.jpg and FRAME 644_2.jpg.
# Augmented frame saved as FRAME 645_2.jpg and FRAME 645_2.jpg.
# Augmented frame saved as FRAME 646_2.jpg and FRAME 646_2.jpg.
# Augmented frame saved as FRAME 647_2.jpg and FRAME 647_2.jpg.
# Augmented frame saved as FRAME 648_2.jpg and FRAME 648_2.jpg.
# Augmented frame saved as FRAME 649_2.jpg and FRAME 649_2.jpg.
# Augmented frame saved as FRAME 65_2.jpg and FRAME 65_2.jpg.
# Augmented frame saved as FRAME 650_2.jpg and FRAME 650_2.jpg.
# Augmented frame saved as FRAME 651_2.jpg and FRAME 651_2.jpg.
# Augmented frame saved as FRAME 652_2.jpg and FRAME 652_2.jpg.
# Augmented frame saved as FRAME 653_2.jpg and FRAME 653_2.jpg.
# Augmented frame saved as FRAME 654_2.jpg and FRAME 654_2.jpg.
# Augmented frame saved as FRAME 655_2.jpg and FRAME 655_2.jpg.
# Augmented frame saved as FRAME 656_2.jpg and FRAME 656_2.jpg.
# Augmented frame saved as FRAME 657_2.jpg and FRAME 657_2.jpg.
# Augmented frame saved as FRAME 658_2.jpg and FRAME 658_2.jpg.
# Augmented frame saved as FRAME 659_2.jpg and FRAME 659_2.jpg.
# Augmented frame saved as FRAME 66_2.jpg and FRAME 66_2.jpg.
# Augmented frame saved as FRAME 660_2.jpg and FRAME 660_2.jpg.
# Augmented frame saved as FRAME 661_2.jpg and FRAME 661_2.jpg.
# Augmented frame saved as FRAME 662_2.jpg and FRAME 662_2.jpg.
# Augmented frame saved as FRAME 663_2.jpg and FRAME 663_2.jpg.
# Augmented frame saved as FRAME 664_2.jpg and FRAME 664_2.jpg.
# Augmented frame saved as FRAME 665_2.jpg and FRAME 665_2.jpg.
# Augmented frame saved as FRAME 666_2.jpg and FRAME 666_2.jpg.
# Augmented frame saved as FRAME 667_2.jpg and FRAME 667_2.jpg.
# Augmented frame saved as FRAME 668_2.jpg and FRAME 668_2.jpg.
# Augmented frame saved as FRAME 669_2.jpg and FRAME 669_2.jpg.
# Augmented frame saved as FRAME 67_2.jpg and FRAME 67_2.jpg.
# Augmented frame saved as FRAME 670_2.jpg and FRAME 670_2.jpg.
# Augmented frame saved as FRAME 671_2.jpg and FRAME 671_2.jpg.
# Augmented frame saved as FRAME 672_2.jpg and FRAME 672_2.jpg.
# Augmented frame saved as FRAME 673_2.jpg and FRAME 673_2.jpg.
# Augmented frame saved as FRAME 674_2.jpg and FRAME 674_2.jpg.
# Augmented frame saved as FRAME 675_2.jpg and FRAME 675_2.jpg.
# Augmented frame saved as FRAME 676_2.jpg and FRAME 676_2.jpg.
# Augmented frame saved as FRAME 677_2.jpg and FRAME 677_2.jpg.
# Augmented frame saved as FRAME 678_2.jpg and FRAME 678_2.jpg.
# Augmented frame saved as FRAME 679_2.jpg and FRAME 679_2.jpg.
# Augmented frame saved as FRAME 68_2.jpg and FRAME 68_2.jpg.
# Augmented frame saved as FRAME 680_2.jpg and FRAME 680_2.jpg.
# Augmented frame saved as FRAME 681_2.jpg and FRAME 681_2.jpg.
# Augmented frame saved as FRAME 682_2.jpg and FRAME 682_2.jpg.
# Augmented frame saved as FRAME 683_2.jpg and FRAME 683_2.jpg.
# Augmented frame saved as FRAME 684_2.jpg and FRAME 684_2.jpg.
# Augmented frame saved as FRAME 685_2.jpg and FRAME 685_2.jpg.
# Augmented frame saved as FRAME 686_2.jpg and FRAME 686_2.jpg.
# Augmented frame saved as FRAME 687_2.jpg and FRAME 687_2.jpg.
# Augmented frame saved as FRAME 688_2.jpg and FRAME 688_2.jpg.
# Augmented frame saved as FRAME 689_2.jpg and FRAME 689_2.jpg.
# Augmented frame saved as FRAME 69_2.jpg and FRAME 69_2.jpg.
# Augmented frame saved as FRAME 690_2.jpg and FRAME 690_2.jpg.
# Augmented frame saved as FRAME 691_2.jpg and FRAME 691_2.jpg.
# Augmented frame saved as FRAME 692_2.jpg and FRAME 692_2.jpg.
# Augmented frame saved as FRAME 693_2.jpg and FRAME 693_2.jpg.
# Augmented frame saved as FRAME 694_2.jpg and FRAME 694_2.jpg.
# Augmented frame saved as FRAME 695_2.jpg and FRAME 695_2.jpg.
# Augmented frame saved as FRAME 696_2.jpg and FRAME 696_2.jpg.
# Augmented frame saved as FRAME 697_2.jpg and FRAME 697_2.jpg.
# Augmented frame saved as FRAME 698_2.jpg and FRAME 698_2.jpg.
# Augmented frame saved as FRAME 699_2.jpg and FRAME 699_2.jpg.
# Augmented frame saved as FRAME 7_2.jpg and FRAME 7_2.jpg.
# Augmented frame saved as FRAME 70_2.jpg and FRAME 70_2.jpg.
# Augmented frame saved as FRAME 700_2.jpg and FRAME 700_2.jpg.
# Augmented frame saved as FRAME 701_2.jpg and FRAME 701_2.jpg.
# Augmented frame saved as FRAME 702_2.jpg and FRAME 702_2.jpg.
# Augmented frame saved as FRAME 703_2.jpg and FRAME 703_2.jpg.
# Augmented frame saved as FRAME 704_2.jpg and FRAME 704_2.jpg.
# Augmented frame saved as FRAME 705_2.jpg and FRAME 705_2.jpg.
# Augmented frame saved as FRAME 706_2.jpg and FRAME 706_2.jpg.
# Augmented frame saved as FRAME 707_2.jpg and FRAME 707_2.jpg.
# Augmented frame saved as FRAME 708_2.jpg and FRAME 708_2.jpg.
# Augmented frame saved as FRAME 709_2.jpg and FRAME 709_2.jpg.
# Augmented frame saved as FRAME 71_2.jpg and FRAME 71_2.jpg.
# Augmented frame saved as FRAME 710_2.jpg and FRAME 710_2.jpg.
# Augmented frame saved as FRAME 711_2.jpg and FRAME 711_2.jpg.
# Augmented frame saved as FRAME 712_2.jpg and FRAME 712_2.jpg.
# Augmented frame saved as FRAME 713_2.jpg and FRAME 713_2.jpg.
# Augmented frame saved as FRAME 714_2.jpg and FRAME 714_2.jpg.
# Augmented frame saved as FRAME 715_2.jpg and FRAME 715_2.jpg.
# Augmented frame saved as FRAME 716_2.jpg and FRAME 716_2.jpg.
# Augmented frame saved as FRAME 717_2.jpg and FRAME 717_2.jpg.
# Augmented frame saved as FRAME 718_2.jpg and FRAME 718_2.jpg.
# Augmented frame saved as FRAME 719_2.jpg and FRAME 719_2.jpg.
# Augmented frame saved as FRAME 72_2.jpg and FRAME 72_2.jpg.
# Augmented frame saved as FRAME 720_2.jpg and FRAME 720_2.jpg.
# Augmented frame saved as FRAME 721_2.jpg and FRAME 721_2.jpg.
# Augmented frame saved as FRAME 722_2.jpg and FRAME 722_2.jpg.
# Augmented frame saved as FRAME 723_2.jpg and FRAME 723_2.jpg.
# Augmented frame saved as FRAME 724_2.jpg and FRAME 724_2.jpg.
# Augmented frame saved as FRAME 725_2.jpg and FRAME 725_2.jpg.
# Augmented frame saved as FRAME 726_2.jpg and FRAME 726_2.jpg.
# Augmented frame saved as FRAME 727_2.jpg and FRAME 727_2.jpg.
# Augmented frame saved as FRAME 728_2.jpg and FRAME 728_2.jpg.
# Augmented frame saved as FRAME 729_2.jpg and FRAME 729_2.jpg.
# Augmented frame saved as FRAME 73_2.jpg and FRAME 73_2.jpg.
# Augmented frame saved as FRAME 730_2.jpg and FRAME 730_2.jpg.
# Augmented frame saved as FRAME 731_2.jpg and FRAME 731_2.jpg.
# Augmented frame saved as FRAME 732_2.jpg and FRAME 732_2.jpg.
# Augmented frame saved as FRAME 733_2.jpg and FRAME 733_2.jpg.
# Augmented frame saved as FRAME 734_2.jpg and FRAME 734_2.jpg.
# Augmented frame saved as FRAME 735_2.jpg and FRAME 735_2.jpg.
# Augmented frame saved as FRAME 736_2.jpg and FRAME 736_2.jpg.
# Augmented frame saved as FRAME 737_2.jpg and FRAME 737_2.jpg.
# Augmented frame saved as FRAME 738_2.jpg and FRAME 738_2.jpg.
# Augmented frame saved as FRAME 739_2.jpg and FRAME 739_2.jpg.
# Augmented frame saved as FRAME 74_2.jpg and FRAME 74_2.jpg.
# Augmented frame saved as FRAME 740_2.jpg and FRAME 740_2.jpg.
# Augmented frame saved as FRAME 741_2.jpg and FRAME 741_2.jpg.
# Augmented frame saved as FRAME 742_2.jpg and FRAME 742_2.jpg.
# Augmented frame saved as FRAME 743_2.jpg and FRAME 743_2.jpg.
# Augmented frame saved as FRAME 744_2.jpg and FRAME 744_2.jpg.
# Augmented frame saved as FRAME 745_2.jpg and FRAME 745_2.jpg.
# Augmented frame saved as FRAME 746_2.jpg and FRAME 746_2.jpg.
# Augmented frame saved as FRAME 747_2.jpg and FRAME 747_2.jpg.
# Augmented frame saved as FRAME 748_2.jpg and FRAME 748_2.jpg.
# Augmented frame saved as FRAME 749_2.jpg and FRAME 749_2.jpg.
# Augmented frame saved as FRAME 75_2.jpg and FRAME 75_2.jpg.
# Augmented frame saved as FRAME 750_2.jpg and FRAME 750_2.jpg.
# Augmented frame saved as FRAME 751_2.jpg and FRAME 751_2.jpg.
# Augmented frame saved as FRAME 752_2.jpg and FRAME 752_2.jpg.
# Augmented frame saved as FRAME 753_2.jpg and FRAME 753_2.jpg.
# Augmented frame saved as FRAME 754_2.jpg and FRAME 754_2.jpg.
# Augmented frame saved as FRAME 755_2.jpg and FRAME 755_2.jpg.
# Augmented frame saved as FRAME 756_2.jpg and FRAME 756_2.jpg.
# Augmented frame saved as FRAME 757_2.jpg and FRAME 757_2.jpg.
# Augmented frame saved as FRAME 758_2.jpg and FRAME 758_2.jpg.
# Augmented frame saved as FRAME 759_2.jpg and FRAME 759_2.jpg.
# Augmented frame saved as FRAME 76_2.jpg and FRAME 76_2.jpg.
# Augmented frame saved as FRAME 760_2.jpg and FRAME 760_2.jpg.
# Augmented frame saved as FRAME 761_2.jpg and FRAME 761_2.jpg.
# Augmented frame saved as FRAME 762_2.jpg and FRAME 762_2.jpg.
# Augmented frame saved as FRAME 763_2.jpg and FRAME 763_2.jpg.
# Augmented frame saved as FRAME 764_2.jpg and FRAME 764_2.jpg.
# Augmented frame saved as FRAME 765_2.jpg and FRAME 765_2.jpg.
# Augmented frame saved as FRAME 766_2.jpg and FRAME 766_2.jpg.
# Augmented frame saved as FRAME 767_2.jpg and FRAME 767_2.jpg.
# Augmented frame saved as FRAME 768_2.jpg and FRAME 768_2.jpg.
# Augmented frame saved as FRAME 769_2.jpg and FRAME 769_2.jpg.
# Augmented frame saved as FRAME 77_2.jpg and FRAME 77_2.jpg.
# Augmented frame saved as FRAME 770_2.jpg and FRAME 770_2.jpg.
# Augmented frame saved as FRAME 771_2.jpg and FRAME 771_2.jpg.
# Augmented frame saved as FRAME 772_2.jpg and FRAME 772_2.jpg.
# Augmented frame saved as FRAME 773_2.jpg and FRAME 773_2.jpg.
# Augmented frame saved as FRAME 774_2.jpg and FRAME 774_2.jpg.
# Augmented frame saved as FRAME 775_2.jpg and FRAME 775_2.jpg.
# Augmented frame saved as FRAME 776_2.jpg and FRAME 776_2.jpg.
# Augmented frame saved as FRAME 777_2.jpg and FRAME 777_2.jpg.
# Augmented frame saved as FRAME 778_2.jpg and FRAME 778_2.jpg.
# Augmented frame saved as FRAME 779_2.jpg and FRAME 779_2.jpg.
# Augmented frame saved as FRAME 78_2.jpg and FRAME 78_2.jpg.
# Augmented frame saved as FRAME 780_2.jpg and FRAME 780_2.jpg.
# Augmented frame saved as FRAME 781_2.jpg and FRAME 781_2.jpg.
# Augmented frame saved as FRAME 782_2.jpg and FRAME 782_2.jpg.
# Augmented frame saved as FRAME 783_2.jpg and FRAME 783_2.jpg.
# Augmented frame saved as FRAME 784_2.jpg and FRAME 784_2.jpg.
# Augmented frame saved as FRAME 785_2.jpg and FRAME 785_2.jpg.
# Augmented frame saved as FRAME 786_2.jpg and FRAME 786_2.jpg.
# Augmented frame saved as FRAME 787_2.jpg and FRAME 787_2.jpg.
# Augmented frame saved as FRAME 788_2.jpg and FRAME 788_2.jpg.
# Augmented frame saved as FRAME 789_2.jpg and FRAME 789_2.jpg.
# Augmented frame saved as FRAME 79_2.jpg and FRAME 79_2.jpg.
# Augmented frame saved as FRAME 790_2.jpg and FRAME 790_2.jpg.
# Augmented frame saved as FRAME 791_2.jpg and FRAME 791_2.jpg.
# Augmented frame saved as FRAME 792_2.jpg and FRAME 792_2.jpg.
# Augmented frame saved as FRAME 793_2.jpg and FRAME 793_2.jpg.
# Augmented frame saved as FRAME 794_2.jpg and FRAME 794_2.jpg.
# Augmented frame saved as FRAME 795_2.jpg and FRAME 795_2.jpg.
# Augmented frame saved as FRAME 796_2.jpg and FRAME 796_2.jpg.
# Augmented frame saved as FRAME 797_2.jpg and FRAME 797_2.jpg.
# Augmented frame saved as FRAME 798_2.jpg and FRAME 798_2.jpg.
# Augmented frame saved as FRAME 799_2.jpg and FRAME 799_2.jpg.
# Augmented frame saved as FRAME 8_2.jpg and FRAME 8_2.jpg.
# Augmented frame saved as FRAME 80_2.jpg and FRAME 80_2.jpg.
# Augmented frame saved as FRAME 800_2.jpg and FRAME 800_2.jpg.
# Augmented frame saved as FRAME 801_2.jpg and FRAME 801_2.jpg.
# Augmented frame saved as FRAME 802_2.jpg and FRAME 802_2.jpg.
# Augmented frame saved as FRAME 803_2.jpg and FRAME 803_2.jpg.
# Augmented frame saved as FRAME 804_2.jpg and FRAME 804_2.jpg.
# Augmented frame saved as FRAME 805_2.jpg and FRAME 805_2.jpg.
# Augmented frame saved as FRAME 806_2.jpg and FRAME 806_2.jpg.
# Augmented frame saved as FRAME 807_2.jpg and FRAME 807_2.jpg.
# Augmented frame saved as FRAME 808_2.jpg and FRAME 808_2.jpg.
# Augmented frame saved as FRAME 809_2.jpg and FRAME 809_2.jpg.
# Augmented frame saved as FRAME 81_2.jpg and FRAME 81_2.jpg.
# Augmented frame saved as FRAME 810_2.jpg and FRAME 810_2.jpg.
# Augmented frame saved as FRAME 811_2.jpg and FRAME 811_2.jpg.
# Augmented frame saved as FRAME 812_2.jpg and FRAME 812_2.jpg.
# Augmented frame saved as FRAME 813_2.jpg and FRAME 813_2.jpg.
# Augmented frame saved as FRAME 814_2.jpg and FRAME 814_2.jpg.
# Augmented frame saved as FRAME 815_2.jpg and FRAME 815_2.jpg.
# Augmented frame saved as FRAME 816_2.jpg and FRAME 816_2.jpg.
# Augmented frame saved as FRAME 817_2.jpg and FRAME 817_2.jpg.
# Augmented frame saved as FRAME 818_2.jpg and FRAME 818_2.jpg.
# Augmented frame saved as FRAME 819_2.jpg and FRAME 819_2.jpg.
# Augmented frame saved as FRAME 82_2.jpg and FRAME 82_2.jpg.
# Augmented frame saved as FRAME 820_2.jpg and FRAME 820_2.jpg.
# Augmented frame saved as FRAME 821_2.jpg and FRAME 821_2.jpg.
# Augmented frame saved as FRAME 822_2.jpg and FRAME 822_2.jpg.
# Augmented frame saved as FRAME 823_2.jpg and FRAME 823_2.jpg.
# Augmented frame saved as FRAME 824_2.jpg and FRAME 824_2.jpg.
# Augmented frame saved as FRAME 825_2.jpg and FRAME 825_2.jpg.
# Augmented frame saved as FRAME 826_2.jpg and FRAME 826_2.jpg.
# Augmented frame saved as FRAME 827_2.jpg and FRAME 827_2.jpg.
# Augmented frame saved as FRAME 828_2.jpg and FRAME 828_2.jpg.
# Augmented frame saved as FRAME 829_2.jpg and FRAME 829_2.jpg.
# Augmented frame saved as FRAME 83_2.jpg and FRAME 83_2.jpg.
# Augmented frame saved as FRAME 830_2.jpg and FRAME 830_2.jpg.
# Augmented frame saved as FRAME 831_2.jpg and FRAME 831_2.jpg.
# Augmented frame saved as FRAME 832_2.jpg and FRAME 832_2.jpg.
# Augmented frame saved as FRAME 833_2.jpg and FRAME 833_2.jpg.
# Augmented frame saved as FRAME 834_2.jpg and FRAME 834_2.jpg.
# Augmented frame saved as FRAME 835_2.jpg and FRAME 835_2.jpg.
# Augmented frame saved as FRAME 836_2.jpg and FRAME 836_2.jpg.
# Augmented frame saved as FRAME 837_2.jpg and FRAME 837_2.jpg.
# Augmented frame saved as FRAME 838_2.jpg and FRAME 838_2.jpg.
# Augmented frame saved as FRAME 839_2.jpg and FRAME 839_2.jpg.
# Augmented frame saved as FRAME 84_2.jpg and FRAME 84_2.jpg.
# Augmented frame saved as FRAME 840_2.jpg and FRAME 840_2.jpg.
# Augmented frame saved as FRAME 841_2.jpg and FRAME 841_2.jpg.
# Augmented frame saved as FRAME 842_2.jpg and FRAME 842_2.jpg.
# Augmented frame saved as FRAME 843_2.jpg and FRAME 843_2.jpg.
# Augmented frame saved as FRAME 844_2.jpg and FRAME 844_2.jpg.
# Augmented frame saved as FRAME 845_2.jpg and FRAME 845_2.jpg.
# Augmented frame saved as FRAME 846_2.jpg and FRAME 846_2.jpg.
# Augmented frame saved as FRAME 847_2.jpg and FRAME 847_2.jpg.
# Augmented frame saved as FRAME 848_2.jpg and FRAME 848_2.jpg.
# Augmented frame saved as FRAME 849_2.jpg and FRAME 849_2.jpg.
# Augmented frame saved as FRAME 85_2.jpg and FRAME 85_2.jpg.
# Augmented frame saved as FRAME 850_2.jpg and FRAME 850_2.jpg.
# Augmented frame saved as FRAME 851_2.jpg and FRAME 851_2.jpg.
# Augmented frame saved as FRAME 852_2.jpg and FRAME 852_2.jpg.
# Augmented frame saved as FRAME 853_2.jpg and FRAME 853_2.jpg.
# Augmented frame saved as FRAME 854_2.jpg and FRAME 854_2.jpg.
# Augmented frame saved as FRAME 855_2.jpg and FRAME 855_2.jpg.
# Augmented frame saved as FRAME 856_2.jpg and FRAME 856_2.jpg.
# Augmented frame saved as FRAME 857_2.jpg and FRAME 857_2.jpg.
# Augmented frame saved as FRAME 858_2.jpg and FRAME 858_2.jpg.
# Augmented frame saved as FRAME 859_2.jpg and FRAME 859_2.jpg.
# Augmented frame saved as FRAME 86_2.jpg and FRAME 86_2.jpg.
# Augmented frame saved as FRAME 860_2.jpg and FRAME 860_2.jpg.
# Augmented frame saved as FRAME 861_2.jpg and FRAME 861_2.jpg.
# Augmented frame saved as FRAME 862_2.jpg and FRAME 862_2.jpg.
# Augmented frame saved as FRAME 863_2.jpg and FRAME 863_2.jpg.
# Augmented frame saved as FRAME 864_2.jpg and FRAME 864_2.jpg.
# Augmented frame saved as FRAME 865_2.jpg and FRAME 865_2.jpg.
# Augmented frame saved as FRAME 866_2.jpg and FRAME 866_2.jpg.
# Augmented frame saved as FRAME 867_2.jpg and FRAME 867_2.jpg.
# Augmented frame saved as FRAME 868_2.jpg and FRAME 868_2.jpg.
# Augmented frame saved as FRAME 869_2.jpg and FRAME 869_2.jpg.
# Augmented frame saved as FRAME 87_2.jpg and FRAME 87_2.jpg.
# Augmented frame saved as FRAME 870_2.jpg and FRAME 870_2.jpg.
# Augmented frame saved as FRAME 871_2.jpg and FRAME 871_2.jpg.
# Augmented frame saved as FRAME 872_2.jpg and FRAME 872_2.jpg.
# Augmented frame saved as FRAME 873_2.jpg and FRAME 873_2.jpg.
# Augmented frame saved as FRAME 874_2.jpg and FRAME 874_2.jpg.
# Augmented frame saved as FRAME 875_2.jpg and FRAME 875_2.jpg.
# Augmented frame saved as FRAME 876_2.jpg and FRAME 876_2.jpg.
# Augmented frame saved as FRAME 877_2.jpg and FRAME 877_2.jpg.
# Augmented frame saved as FRAME 878_2.jpg and FRAME 878_2.jpg.
# Augmented frame saved as FRAME 879_2.jpg and FRAME 879_2.jpg.
# Augmented frame saved as FRAME 88_2.jpg and FRAME 88_2.jpg.
# Augmented frame saved as FRAME 880_2.jpg and FRAME 880_2.jpg.
# Augmented frame saved as FRAME 881_2.jpg and FRAME 881_2.jpg.
# Augmented frame saved as FRAME 882_2.jpg and FRAME 882_2.jpg.
# Augmented frame saved as FRAME 89_2.jpg and FRAME 89_2.jpg.
# Augmented frame saved as FRAME 9_2.jpg and FRAME 9_2.jpg.
# Augmented frame saved as FRAME 90_2.jpg and FRAME 90_2.jpg.
# Augmented frame saved as FRAME 91_2.jpg and FRAME 91_2.jpg.
# Augmented frame saved as FRAME 92_2.jpg and FRAME 92_2.jpg.
# Augmented frame saved as FRAME 93_2.jpg and FRAME 93_2.jpg.
# Augmented frame saved as FRAME 94_2.jpg and FRAME 94_2.jpg.
# Augmented frame saved as FRAME 95_2.jpg and FRAME 95_2.jpg.
# Augmented frame saved as FRAME 96_2.jpg and FRAME 96_2.jpg.
# Augmented frame saved as FRAME 98_2.jpg and FRAME 98_2.jpg.

# %%
#Create Data lables
# Define directories
scaler = MinMaxScaler()
root_directory = "/content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code"
desired_shape = (160, 256)  # Specify the desired shape
output_label_folder = "/content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels"  # Folder to save labels

# Create the label folder if it doesn't exist
os.makedirs(output_label_folder, exist_ok=True)

image_folder = os.path.join(root_directory, "image")
mask_folder = os.path.join(root_directory, "mask")

# Read images and corresponding masks
image_files = sorted(os.listdir(image_folder))  # Sort to maintain order

for image_name in image_files:
    if image_name.endswith(".jpg"):
        image_path = os.path.join(image_folder, image_name)
        mask_path = os.path.join(mask_folder, image_name)  # Assume masks have the same name

        print(f"Processing image: {image_path}")
        print(f"Processing mask: {mask_path}")

        # Check if corresponding mask exists
        if os.path.exists(mask_path):
            msk = cv2.imread(mask_path, 1)

            if msk is not None:
                # Resize mask
                msk = cv2.resize(msk, desired_shape)
                msk = cv2.cvtColor(msk, cv2.COLOR_BGR2RGB)

                # Convert mask to binary label
                pomegranate = [255, 255, 255]  # White for pomegranates
                label = np.zeros(msk.shape[:2], dtype=np.uint8)
                label[np.all(msk == pomegranate, axis=-1)] = 1  # 1 for pomegranates, 0 for background

                # Save the label as an `.npy` file
                label_save_path = os.path.join(output_label_folder, image_name.replace('.jpg', '.npy'))
                np.save(label_save_path, label)
                print(f"Saved label for {image_name} at {label_save_path}")
            else:
                print(f"Error loading mask: {mask_path}")
        else:
            print(f"Mask not found for image: {image_path}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 155.jpg
# Saved label for FRAME 155.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 155.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 155_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 155_2.jpg
# Saved label for FRAME 155_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 155_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 155_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 155_2_2.jpg
# Saved label for FRAME 155_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 155_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 156.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 156.jpg
# Saved label for FRAME 156.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 156.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 156_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 156_2.jpg
# Saved label for FRAME 156_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 156_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 156_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 156_2_2.jpg
# Saved label for FRAME 156_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 156_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 157.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 157.jpg
# Saved label for FRAME 157.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 157.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 157_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 157_2.jpg
# Saved label for FRAME 157_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 157_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 157_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 157_2_2.jpg
# Saved label for FRAME 157_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 157_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 158.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 158.jpg
# Saved label for FRAME 158.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 158.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 158_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 158_2.jpg
# Saved label for FRAME 158_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 158_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 158_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 158_2_2.jpg
# Saved label for FRAME 158_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 158_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 159.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 159.jpg
# Saved label for FRAME 159.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 159.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 159_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 159_2.jpg
# Saved label for FRAME 159_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 159_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 159_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 159_2_2.jpg
# Saved label for FRAME 159_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 159_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 15_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 15_2.jpg
# Saved label for FRAME 15_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 15_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 15_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 15_2_2.jpg
# Saved label for FRAME 15_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 15_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 16.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 16.jpg
# Saved label for FRAME 16.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 16.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 160.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 160.jpg
# Saved label for FRAME 160.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 160.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 160_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 160_2.jpg
# Saved label for FRAME 160_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 160_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 160_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 160_2_2.jpg
# Saved label for FRAME 160_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 160_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 161.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 161.jpg
# Saved label for FRAME 161.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 161.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 161_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 161_2.jpg
# Saved label for FRAME 161_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 161_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 161_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 161_2_2.jpg
# Saved label for FRAME 161_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 161_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 162.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 162.jpg
# Saved label for FRAME 162.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 162.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 162_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 162_2.jpg
# Saved label for FRAME 162_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 162_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 162_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 162_2_2.jpg
# Saved label for FRAME 162_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 162_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 163.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 163.jpg
# Saved label for FRAME 163.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 163.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 163_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 163_2.jpg
# Saved label for FRAME 163_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 163_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 163_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 163_2_2.jpg
# Saved label for FRAME 163_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 163_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 164.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 164.jpg
# Saved label for FRAME 164.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 164.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 164_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 164_2.jpg
# Saved label for FRAME 164_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 164_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 164_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 164_2_2.jpg
# Saved label for FRAME 164_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 164_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 165.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 165.jpg
# Saved label for FRAME 165.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 165.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 165_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 165_2.jpg
# Saved label for FRAME 165_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 165_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 165_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 165_2_2.jpg
# Saved label for FRAME 165_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 165_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 166.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 166.jpg
# Saved label for FRAME 166.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 166.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 166_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 166_2.jpg
# Saved label for FRAME 166_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 166_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 166_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 166_2_2.jpg
# Saved label for FRAME 166_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 166_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 167.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 167.jpg
# Saved label for FRAME 167.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 167.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 167_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 167_2.jpg
# Saved label for FRAME 167_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 167_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 167_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 167_2_2.jpg
# Saved label for FRAME 167_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 167_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 168.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 168.jpg
# Saved label for FRAME 168.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 168.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 168_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 168_2.jpg
# Saved label for FRAME 168_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 168_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 168_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 168_2_2.jpg
# Saved label for FRAME 168_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 168_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 169.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 169.jpg
# Saved label for FRAME 169.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 169.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 169_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 169_2.jpg
# Saved label for FRAME 169_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 169_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 169_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 169_2_2.jpg
# Saved label for FRAME 169_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 169_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 16_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 16_2.jpg
# Saved label for FRAME 16_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 16_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 16_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 16_2_2.jpg
# Saved label for FRAME 16_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 16_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 17.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 17.jpg
# Saved label for FRAME 17.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 17.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 170.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 170.jpg
# Saved label for FRAME 170.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 170.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 170_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 170_2.jpg
# Saved label for FRAME 170_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 170_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 170_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 170_2_2.jpg
# Saved label for FRAME 170_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 170_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 171.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 171.jpg
# Saved label for FRAME 171.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 171.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 171_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 171_2.jpg
# Saved label for FRAME 171_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 171_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 171_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 171_2_2.jpg
# Saved label for FRAME 171_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 171_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 172.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 172.jpg
# Saved label for FRAME 172.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 172.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 172_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 172_2.jpg
# Saved label for FRAME 172_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 172_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 172_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 172_2_2.jpg
# Saved label for FRAME 172_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 172_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 173.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 173.jpg
# Saved label for FRAME 173.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 173.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 173_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 173_2.jpg
# Saved label for FRAME 173_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 173_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 173_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 173_2_2.jpg
# Saved label for FRAME 173_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 173_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 174.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 174.jpg
# Saved label for FRAME 174.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 174.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 174_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 174_2.jpg
# Saved label for FRAME 174_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 174_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 174_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 174_2_2.jpg
# Saved label for FRAME 174_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 174_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 175.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 175.jpg
# Saved label for FRAME 175.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 175.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 175_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 175_2.jpg
# Saved label for FRAME 175_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 175_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 175_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 175_2_2.jpg
# Saved label for FRAME 175_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 175_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 176.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 176.jpg
# Saved label for FRAME 176.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 176.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 176_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 176_2.jpg
# Saved label for FRAME 176_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 176_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 176_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 176_2_2.jpg
# Saved label for FRAME 176_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 176_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 177.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 177.jpg
# Saved label for FRAME 177.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 177.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 177_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 177_2.jpg
# Saved label for FRAME 177_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 177_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 177_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 177_2_2.jpg
# Saved label for FRAME 177_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 177_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 178.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 178.jpg
# Saved label for FRAME 178.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 178.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 178_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 178_2.jpg
# Saved label for FRAME 178_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 178_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 178_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 178_2_2.jpg
# Saved label for FRAME 178_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 178_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 179.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 179.jpg
# Saved label for FRAME 179.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 179.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 179_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 179_2.jpg
# Saved label for FRAME 179_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 179_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 179_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 179_2_2.jpg
# Saved label for FRAME 179_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 179_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 17_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 17_2.jpg
# Saved label for FRAME 17_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 17_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 17_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 17_2_2.jpg
# Saved label for FRAME 17_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 17_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 18.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 18.jpg
# Saved label for FRAME 18.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 18.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 180.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 180.jpg
# Saved label for FRAME 180.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 180.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 180_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 180_2.jpg
# Saved label for FRAME 180_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 180_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 180_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 180_2_2.jpg
# Saved label for FRAME 180_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 180_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 181.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 181.jpg
# Saved label for FRAME 181.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 181.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 181_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 181_2.jpg
# Saved label for FRAME 181_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 181_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 181_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 181_2_2.jpg
# Saved label for FRAME 181_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 181_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 182.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 182.jpg
# Saved label for FRAME 182.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 182.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 182_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 182_2.jpg
# Saved label for FRAME 182_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 182_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 182_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 182_2_2.jpg
# Saved label for FRAME 182_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 182_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 183.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 183.jpg
# Saved label for FRAME 183.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 183.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 183_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 183_2.jpg
# Saved label for FRAME 183_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 183_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 183_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 183_2_2.jpg
# Saved label for FRAME 183_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 183_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 184.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 184.jpg
# Saved label for FRAME 184.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 184.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 184_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 184_2.jpg
# Saved label for FRAME 184_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 184_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 184_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 184_2_2.jpg
# Saved label for FRAME 184_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 184_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 185.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 185.jpg
# Saved label for FRAME 185.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 185.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 185_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 185_2.jpg
# Saved label for FRAME 185_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 185_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 185_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 185_2_2.jpg
# Saved label for FRAME 185_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 185_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 186.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 186.jpg
# Saved label for FRAME 186.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 186.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 186_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 186_2.jpg
# Saved label for FRAME 186_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 186_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 186_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 186_2_2.jpg
# Saved label for FRAME 186_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 186_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 187.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 187.jpg
# Saved label for FRAME 187.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 187.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 187_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 187_2.jpg
# Saved label for FRAME 187_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 187_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 187_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 187_2_2.jpg
# Saved label for FRAME 187_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 187_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 188.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 188.jpg
# Saved label for FRAME 188.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 188.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 188_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 188_2.jpg
# Saved label for FRAME 188_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 188_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 188_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 188_2_2.jpg
# Saved label for FRAME 188_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 188_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 189.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 189.jpg
# Saved label for FRAME 189.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 189.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 189_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 189_2.jpg
# Saved label for FRAME 189_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 189_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 189_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 189_2_2.jpg
# Saved label for FRAME 189_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 189_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 18_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 18_2.jpg
# Saved label for FRAME 18_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 18_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 18_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 18_2_2.jpg
# Saved label for FRAME 18_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 18_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 19.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 19.jpg
# Saved label for FRAME 19.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 19.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 190.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 190.jpg
# Saved label for FRAME 190.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 190.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 190_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 190_2.jpg
# Saved label for FRAME 190_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 190_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 190_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 190_2_2.jpg
# Saved label for FRAME 190_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 190_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 191.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 191.jpg
# Saved label for FRAME 191.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 191.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 191_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 191_2.jpg
# Saved label for FRAME 191_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 191_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 191_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 191_2_2.jpg
# Saved label for FRAME 191_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 191_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 192.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 192.jpg
# Saved label for FRAME 192.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 192.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 192_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 192_2.jpg
# Saved label for FRAME 192_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 192_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 192_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 192_2_2.jpg
# Saved label for FRAME 192_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 192_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 193.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 193.jpg
# Saved label for FRAME 193.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 193.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 193_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 193_2.jpg
# Saved label for FRAME 193_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 193_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 193_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 193_2_2.jpg
# Saved label for FRAME 193_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 193_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 194.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 194.jpg
# Saved label for FRAME 194.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 194.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 194_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 194_2.jpg
# Saved label for FRAME 194_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 194_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 194_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 194_2_2.jpg
# Saved label for FRAME 194_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 194_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 195.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 195.jpg
# Saved label for FRAME 195.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 195.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 195_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 195_2.jpg
# Saved label for FRAME 195_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 195_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 195_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 195_2_2.jpg
# Saved label for FRAME 195_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 195_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 196.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 196.jpg
# Saved label for FRAME 196.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 196.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 196_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 196_2.jpg
# Saved label for FRAME 196_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 196_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 196_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 196_2_2.jpg
# Saved label for FRAME 196_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 196_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 197.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 197.jpg
# Saved label for FRAME 197.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 197.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 197_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 197_2.jpg
# Saved label for FRAME 197_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 197_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 197_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 197_2_2.jpg
# Saved label for FRAME 197_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 197_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 198.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 198.jpg
# Saved label for FRAME 198.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 198.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 198_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 198_2.jpg
# Saved label for FRAME 198_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 198_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 198_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 198_2_2.jpg
# Saved label for FRAME 198_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 198_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 199.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 199.jpg
# Saved label for FRAME 199.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 199.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 199_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 199_2.jpg
# Saved label for FRAME 199_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 199_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 199_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 199_2_2.jpg
# Saved label for FRAME 199_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 199_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 19_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 19_2.jpg
# Saved label for FRAME 19_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 19_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 19_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 19_2_2.jpg
# Saved label for FRAME 19_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 19_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 1_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 1_2.jpg
# Saved label for FRAME 1_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 1_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 1_2_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 1_2_2.jpg
# Saved label for FRAME 1_2_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 1_2_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 2.jpg
# Saved label for FRAME 2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 20.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 20.jpg
# Saved label for FRAME 20.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 20.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 200.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 200.jpg
# Saved label for FRAME 200.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 200.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 200_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 200_2.jpg
# Saved label for FRAME 200_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 200_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 201.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 201.jpg
# Saved label for FRAME 201.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 201.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 201_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 201_2.jpg
# ...
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 869_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 869_2.jpg
# Saved label for FRAME 869_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 869_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 86_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 86_2.jpg
# Saved label for FRAME 86_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 86_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 87.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 87.jpg
# Saved label for FRAME 87.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 87.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 870.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 870.jpg
# Saved label for FRAME 870.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 870.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 870_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 870_2.jpg
# Saved label for FRAME 870_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 870_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 871.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 871.jpg
# Saved label for FRAME 871.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 871.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 871_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 871_2.jpg
# Saved label for FRAME 871_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 871_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 872.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 872.jpg
# Saved label for FRAME 872.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 872.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 872_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 872_2.jpg
# Saved label for FRAME 872_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 872_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 873.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 873.jpg
# Saved label for FRAME 873.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 873.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 873_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 873_2.jpg
# Saved label for FRAME 873_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 873_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 874.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 874.jpg
# Saved label for FRAME 874.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 874.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 874_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 874_2.jpg
# Saved label for FRAME 874_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 874_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 875.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 875.jpg
# Saved label for FRAME 875.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 875.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 875_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 875_2.jpg
# Saved label for FRAME 875_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 875_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 876.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 876.jpg
# Saved label for FRAME 876.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 876.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 876_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 876_2.jpg
# Saved label for FRAME 876_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 876_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 877.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 877.jpg
# Saved label for FRAME 877.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 877.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 877_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 877_2.jpg
# Saved label for FRAME 877_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 877_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 878.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 878.jpg
# Saved label for FRAME 878.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 878.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 878_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 878_2.jpg
# Saved label for FRAME 878_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 878_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 879.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 879.jpg
# Saved label for FRAME 879.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 879.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 879_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 879_2.jpg
# Saved label for FRAME 879_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 879_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 87_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 87_2.jpg
# Saved label for FRAME 87_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 87_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 88.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 88.jpg
# Saved label for FRAME 88.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 88.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 880.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 880.jpg
# Saved label for FRAME 880.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 880.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 880_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 880_2.jpg
# Saved label for FRAME 880_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 880_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 881.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 881.jpg
# Saved label for FRAME 881.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 881.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 881_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 881_2.jpg
# Saved label for FRAME 881_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 881_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 882.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 882.jpg
# Saved label for FRAME 882.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 882.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 882_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 882_2.jpg
# Saved label for FRAME 882_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 882_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 88_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 88_2.jpg
# Saved label for FRAME 88_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 88_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 89.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 89.jpg
# Saved label for FRAME 89.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 89.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 89_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 89_2.jpg
# Saved label for FRAME 89_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 89_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 8_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 8_2.jpg
# Saved label for FRAME 8_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 8_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 9.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 9.jpg
# Saved label for FRAME 9.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 9.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 90.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 90.jpg
# Saved label for FRAME 90.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 90.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 90_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 90_2.jpg
# Saved label for FRAME 90_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 90_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 91.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 91.jpg
# Saved label for FRAME 91.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 91.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 91_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 91_2.jpg
# Saved label for FRAME 91_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 91_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 92.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 92.jpg
# Saved label for FRAME 92.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 92.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 92_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 92_2.jpg
# Saved label for FRAME 92_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 92_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 93.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 93.jpg
# Saved label for FRAME 93.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 93.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 93_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 93_2.jpg
# Saved label for FRAME 93_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 93_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 94.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 94.jpg
# Saved label for FRAME 94.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 94.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 94_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 94_2.jpg
# Saved label for FRAME 94_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 94_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 95.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 95.jpg
# Saved label for FRAME 95.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 95.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 95_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 95_2.jpg
# Saved label for FRAME 95_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 95_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 96.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 96.jpg
# Saved label for FRAME 96.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 96.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 96_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 96_2.jpg
# Saved label for FRAME 96_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 96_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 98.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 98.jpg
# Saved label for FRAME 98.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 98.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 98_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 98_2.jpg
# Saved label for FRAME 98_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 98_2.npy
# Processing image: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image/FRAME 9_2.jpg
# Processing mask: /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/mask/FRAME 9_2.jpg
# Saved label for FRAME 9_2.jpg at /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels/FRAME 9_2.npy

# %%
#Data Loder
class PomegranateDataset(Dataset):
    def __init__(self, image_paths, label_paths, transform=None, target_size=(160, 256)):
        self.image_paths = image_paths
        self.label_paths = label_paths
        self.transform = transform
        self.target_size = target_size  # Resize to target size

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        # Load image
        image = cv2.imread(self.image_paths[idx])
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        # Load label (from .npy file)
        label = np.load(self.label_paths[idx])

        # Resize both image and label to the target size
        image = cv2.resize(image, self.target_size)
        label = cv2.resize(label, self.target_size, interpolation=cv2.INTER_NEAREST)

        # Apply transformation to the image (e.g., ToTensor and normalization)
        if self.transform:
            image = self.transform(image)

        # Convert label to a tensor
        label = torch.tensor(label, dtype=torch.long)

        return image, label


# Define Transformations for Images
transform = transforms.Compose([
    transforms.ToTensor()  # Convert to Tensor
])

# Get paths for images and labels
image_folder = "/content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/image"
label_folder = "/content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/saved_labels"

image_paths = sorted([os.path.join(image_folder, f) for f in os.listdir(image_folder) if f.endswith(".jpg")])
label_paths = sorted([os.path.join(label_folder, f) for f in os.listdir(label_folder) if f.endswith(".npy")])

# Split the dataset into training and testing
from sklearn.model_selection import train_test_split

image_train_paths, image_test_paths, label_train_paths, label_test_paths = train_test_split(
    image_paths, label_paths, test_size=349, random_state=42, shuffle=True
)

# Create Datasets and DataLoaders
train_dataset = PomegranateDataset(image_train_paths, label_train_paths, transform=transform, target_size=(256, 256))
test_dataset = PomegranateDataset(image_test_paths, label_test_paths, transform=transform, target_size=(256, 256))

train_dataloader = DataLoader(train_dataset, batch_size=4, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=4, shuffle=False)

# Print dataset stats to confirm
print(f"Number of training samples: {len(train_dataset)}")
print(f"Number of testing samples: {len(test_dataset)}")
# Out:
# Number of training samples: 1500
# Number of testing samples: 349

# %%
#Model Run Unet image size of 160 hight and 256 width
NUM_CLASSES = 2  # 2 classes: background and solar panel
GPU = 0
SEED = 2023

torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True
os.environ['PYTHONHASHSEED'] = str(SEED)
torch.cuda.manual_seed_all(SEED)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Initialize model
model = smp.Unet("resnet152", classes=NUM_CLASSES, in_channels=3, encoder_weights="imagenet")
model.to(device)

# Define loss function and optimizer
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=0.001,weight_decay=1e-4)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=2, verbose=True)

# Target size for images and masks (divisible by 32 for Unet)
target_size = (160, 256)  # Replace with the desired size divisible by 32

# Training loop
num_epochs = 30
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0

    for images, lables in train_dataloader:
        # Move images and masks to the device
        images = images.to(device, dtype=torch.float)

        # Convert masks to float for interpolation, then back to long after resizing
        lables = lables.to(device, dtype=torch.float)
        images = F.interpolate(images, size=target_size, mode="bilinear", align_corners=False)
        lables = F.interpolate(lables.unsqueeze(1), size=target_size, mode="nearest").squeeze(1)
        lables = lables.to(dtype=torch.long)  # Convert back to long

        # Zero gradients
        optimizer.zero_grad()

        # Forward pass
        outputs = model(images)

        # Compute loss
        loss = criterion(outputs, lables)

        # Backward pass and optimization
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * images.size(0)

    # Compute average loss for the epoch
    epoch_loss = running_loss / len(train_dataloader.dataset)
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss:.4f}")

    # Step the scheduler
    scheduler.step(epoch_loss)

# %%
# Path to save the model in your Google Drive
save_path = "/content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/unet_model_improve_resnet152.pth"

# Save the model
torch.save(model.state_dict(), save_path)

print(f"Model saved to {save_path}")
# Out:
# Model saved to /content/drive/MyDrive/Thesis/POM-IMG/pom_seg_img_code/unet_model_improve_efficientnet-b7.pth

# %%
from tqdm import tqdm
# Define a function to calculate mIoU
def calculate_miou(y_true, y_pred, num_classes):
    y_true = y_true.flatten()
    y_pred = y_pred.flatten()
    cm = confusion_matrix(y_true, y_pred, labels=list(range(num_classes)))
    iou = np.diag(cm) / (cm.sum(axis=1) + cm.sum(axis=0) - np.diag(cm))
    return np.nanmean(iou)

# Validation function
def validate(model, dataloader, device, num_classes):
    model.eval()
    all_preds = []
    all_masks = []
    with torch.no_grad():
        for images, masks in tqdm(dataloader, desc="Validating"):
            images, masks = images.to(device, dtype=torch.float), masks.to(device)
            outputs = model(images)
            preds = torch.argmax(outputs, dim=1)
            all_preds.append(preds.cpu().numpy())
            all_masks.append(masks.cpu().numpy())

    all_preds = np.concatenate(all_preds)
    all_masks = np.concatenate(all_masks)

    # Calculate mIoU
    miou = calculate_miou(all_masks, all_preds, num_classes)

    # Calculate precision, recall, and F1-score
    precision = precision_score(all_masks.flatten(), all_preds.flatten())
    recall = recall_score(all_masks.flatten(), all_preds.flatten())
    f1 = f1_score(all_masks.flatten(), all_preds.flatten())

    return miou, precision, recall, f1

# Assuming the model is already defined and trained, and the test_dataloader is set up
num_classes = 2  # Set this to the number of classes in your dataset
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Validate the model on the first test set
miou1, precision1, recall1, f1_1 = validate(model, test_dataloader, device, num_classes)
print(f"Dataset 1 - mIoU: {miou1:.4f}, Precision: {precision1:.4f}, Recall: {recall1:.4f}, F1-Score: {f1_1:.4f}")
# Out:
# Validating: 100%|██████████| 88/88 [00:51<00:00,  1.71it/s]
# Dataset 1 - mIoU: 0.8458, Precision: 0.8913, Recall: 0.7871, F1-Score: 0.8360

# %%
def plot_predictions(model, dataloader, device, num_images=5):
    model.eval()
    images, masks = next(iter(dataloader))
    images, masks = images.to(device, dtype=torch.float), masks.to(device)

    with torch.no_grad():
        outputs = model(images)
        preds = torch.argmax(outputs, dim=1)

    images = images.cpu().numpy()
    masks = masks.cpu().numpy()
    preds = preds.cpu().numpy()

    # Limit the number of images to the batch size
    num_images = min(num_images, len(images))

    fig, axes = plt.subplots(num_images, 3, figsize=(15, num_images * 5))
    for i in range(num_images):
        axes[i, 0].imshow(images[i].transpose(1, 2, 0))
        axes[i, 0].set_title('Test Image')
        axes[i, 0].axis('off')

        axes[i, 1].imshow(masks[i], cmap='gray')
        axes[i, 1].set_title('Ground Truth Mask')
        axes[i, 1].axis('off')

        axes[i, 2].imshow(preds[i], cmap='gray')
        axes[i, 2].set_title('Predicted Mask')
        axes[i, 2].axis('off')

    plt.tight_layout()
    plt.show()

# Plot predictions for a few test images
plot_predictions(model, test_dataloader, device, num_images=5)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
